# %% [markdown]
# # Final Project - Machine Learning 2024/25
#
# ### Unsupervised Learning algorithms - Clustering groups that are (not) prone to heart disease

# %%
# import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.cluster import KMeans

# %%
# read preprocessed data
data = pd.read_csv("data/preprocessedData.csv")

# %%
data
# Out:
#         Unnamed: 0  General_Health  Checkup  Exercise  Heart_Disease  \
# 0                0               1        4         0              0
# 1                1               4        5         0              1
# 2                2               4        5         1              0
# 3                3               1        5         1              1
# 4                4               3        5         0              0
# ...            ...             ...      ...       ...            ...
# 308849      308849               4        5         1              0
# 308850      308850               2        3         1              0
# 308851      308851               4        2         1              0
# 308852      308852               4        5         1              0
# 308853      308853               5        5         1              0
#
#         Skin_Cancer  Other_Cancer  Depression  Diabetes  Arthritis  Sex  \
# ...

# %%
# separate the predictors and the criterion variable
data = data.drop('Heart_Disease', axis=1)  
criterion = data['Heart_Disease']

# %% [markdown]
# ### K-Means

# %%
kmeans = KMeans(n_clusters=2, n_init="auto").fit(data)
kmeans.labels_
kmeans.cluster_centers_
# Out:
# array([[2.31568000e+05, 3.52667706e+00, 4.62340284e+00, 7.72486430e-01,
#         8.17164927e-02, 9.56324278e-02, 9.71398257e-02, 2.03414612e-01,
#         1.41255475e-01, 3.32397410e-01, 5.18945986e-01, 8.16648789e+01,
#         1.70504888e+02, 8.36432676e+01, 2.86849728e+01, 4.02546403e-01,
#         4.98877538e+00, 2.98569072e+01, 1.52370173e+01, 6.28504053e+00],
#        [7.71410000e+04, 3.53422607e+00, 4.61254967e+00, 7.77642384e-01,
#         7.99828886e-02, 9.85980309e-02, 9.63359541e-02, 1.97422918e-01,
#         1.36003319e-01, 3.22083444e-01, 5.18410972e-01, 8.16647395e+01,
#         1.70725816e+02, 8.35339395e+01, 2.85673386e+01, 4.08612744e-01,
#         5.20415730e+00, 2.98134532e+01, 1.49836275e+01, 6.30821283e+00]])

# %%
# maybe loop 30 times get average values since kmean is dependend on first random cluster centers
