# %% [markdown]
# # Introduction to Machine Learning — 2024/2025 Unsupervised Learning
#
# This assignment will demonstrate how a learning algorithm can distinguish between two distributions of points generated with different parameters, using no information on the target values.

# %% [markdown]
# ## Exercise 1
# Generate 2D points using a multivariate Gaussian distribution
# 1. Use the code in Fig. 1 to generate two sets, each with 500 points (reduce this number if necessary to obtain better visualizations or faster training runs),
# 2. Each dataset should have different centers, and sets should have a small overlap.
# 3. Add a column and fill it with 1 (one) for the first dataset and 2 (two) on the second, so that you can keep track of which distribution generated each point.
# 4. Join and shuffle the dataset.
# 5. The plot of the first two columns should be similar to the one presented in Fig. 2.
# 6. Write the dataset to a file.

# %%
# import packages
import matplotlib . pyplot as plt 
from matplotlib.patches import Circle
import numpy as np
from numpy import genfromtxt
import random
import math

# %%
# generate data

mean= [3, 3]
cov = [[1, 0], [0, 1]]
a = np.random.multivariate_normal(mean, cov, 500).T

new_col_a = np.ones((1, a.shape[1]))
a = np.append(a, new_col_a, axis = 0)

mean= [-3, -3]
cov = [[2, 0], [0, 5]]
b = np.random.multivariate_normal(mean, cov, 500).T

new_col_b = np.full((1, b.shape[1]), 2)
b = np.append(b, new_col_b, axis = 0)

c = np.concatenate((a, b) , axis = 1) 
c=c.T
np.random.shuffle(c)
c=c.T

x = c[0] 
y=c[1]
labels=c[2]
plt.plot(x, y, "x") 
plt.axis("equal") 
plt .show()

# save and load data
np.savetxt("testData.csv", c, delimiter=",")
data = genfromtxt('testData.csv', delimiter=',')

# %% [markdown]
# ### Exercise 1.1 Implement a simple version of K-Means
#
# Start by choosing two random points in the dataset r1 and r2 and apply the following adaptation rule:
#
#     for all x ∈ the dataset do
#         if x is closer to r1 than to r2 then
#             r1 ←(1−α)×r1 +α×x
#         else if x is closer to r2 than to r1 then
#             r2 ←(1−α)×r2 +α×x
#         end if
#     end for

# %%
def getEuclideanDistance(point1x, point1y, point2x, point2y):
    distance = math.sqrt((point1x-point2x)**2+(point1y-point2y)**2)
    return(distance)

# %%
# define parameters
alpha = 0.00001

# choose random k indexes
# copy data for immutability and transpose to sample complete case
cTCopy = c.T
idexOfPoint1, indexOfPoint2= random.sample(range(len(cTCopy)), k=2)

# define the two k points following the random indexes
r1 = cTCopy[idexOfPoint1][:2]
r2 = cTCopy[indexOfPoint2][:2]

# initialize two np.arrays to save clusters
cluster1 = []
cluster2 = []

# save all consecutive values of r1 and r2 for the first passage
allValuesOfR1 = []
allValuesOfR2 = []

# implement easy k-means version
for i in range(len(cTCopy)):
    # divide every point in coordinates and label
    coordinate = cTCopy[i][:2]
    trueClusterLabel = cTCopy[i][2]

    # get distance to both k
    distanceToR1 = getEuclideanDistance(r1[0],r1[1], coordinate[0], coordinate[1])
    distanceToR2 = getEuclideanDistance(r2[0],r2[1], coordinate[0], coordinate[1])

    

    # append to cluster of k to which point is closer, swiftly adjust k in position
    if distanceToR1 < distanceToR2:
        allValuesOfR1.append(r1)
        cluster1.append([*coordinate, trueClusterLabel])
        r1 = (1-alpha)*r1+alpha*coordinate
    else:
        allValuesOfR2.append(r2)
        cluster2.append([*coordinate, trueClusterLabel])
        r2 = (1-alpha)*r2+alpha*coordinate

# check length of final clusters to see whether all points have been assigned
print(len(cluster2))
print(len(cluster1))
# Out:
# 208
# 792

# %% [markdown]
# ### Exercise 1.2
# Repeat for 10 times a passage through all the elements of the dataset (i.e. 10 epochs) with α = 10E − 5 and save:
#
# (i) the consecutive values of r1 and r2 for the first passage;
#
# (ii) the values of r1 and r2 at the end of each passage.

# %%
# (ii) the consecutive values of r1 and r2 for the first passage
allValuesOfR1
allValuesOfR2
print(len(allValuesOfR1)+len(allValuesOfR2))
# Out:
# 1000

# %%
# (ii) the values of r1 and r2 at the end of each passage.

# define parameters
alpha = 0.00001

# choose random k indexes
# copy data for immutability and transpose to sample complete case
cTCopy = c.T
idexOfPoint1, indexOfPoint2= random.sample(range(len(cTCopy)), k=2)

# define the two k points following the random indexes
r1 = cTCopy[idexOfPoint1][:2]
r2 = cTCopy[indexOfPoint2][:2]

# initialize lists to store final r1 and r2 values
r1AfterClustering = []
r2AfterClustering = []

# repeat for 10 times:
for i in range(10):

    # implement easy k-means version
    for i in range(len(cTCopy)):
        # divide every point in coordinates and label
        coordinate = cTCopy[i][:2]
        trueClusterLabel = cTCopy[i][2]

        # get distance to both k
        distanceToR1 = getEuclideanDistance(r1[0],r1[1], coordinate[0], coordinate[1])
        distanceToR2 = getEuclideanDistance(r2[0],r2[1], coordinate[0], coordinate[1])

        # append to cluster of k to which point is closer, swiftly adjust k in position
        if distanceToR1 < distanceToR2:
            #cluster1.append([*coordinate, trueClusterLabel])
            r1 = (1-alpha)*r1+alpha*coordinate
        else:
            #cluster2.append([*coordinate, trueClusterLabel])
            r2 = (1-alpha)*r2+alpha*coordinate


    r1AfterClustering.append(r1)
    r2AfterClustering.append(r2)

# %% [markdown]
# ### Exercise 1.3
#
# Plot (i) and (ii) upon the dataset plot in different graphs. Change the value of α and the number of epochs to see the evolution of the representatives clearly. What do you conclude about the evolution of the two points in the different situations? Is there any relation between the final values of the representatives (r1 and r2) and the parameters used to generate the dataset?

# %%
# plot (i) uppon the dataset

x = c[0] 
y=c[1]

xR1 = []
for r1 in allValuesOfR1:
    xR1.append(r1[0])

xR2 = []
for r2 in allValuesOfR2:
    xR2.append(r2[0])

yR1 = []
for r1 in allValuesOfR1:
    yR1.append(r1[1])

yR2 = []
for r2 in allValuesOfR2:
    yR2.append(r2[1])
    
labels=c[2]
plt.plot(x, y, "x") 
plt.plot(xR1, yR1, "o", color = "orange")
plt.plot(xR2, yR2, "o", color = "lightgreen")

plt.axis("equal") 
plt .show()

# %%
# plot (i) uppon the dataset and also include final clustering of round one

xCluster1 = []
for dataPoint in cluster1:
    xCluster1.append(dataPoint[0])

yCluster1 = []
for dataPoint in cluster1:
    yCluster1.append(dataPoint[1])

xCluster2 = []
for dataPoint in cluster2:
    xCluster2.append(dataPoint[0])

yCluster2 = []
for dataPoint in cluster2:
    yCluster2.append(dataPoint[1])


xR1 = []
for r1 in allValuesOfR1:
    xR1.append(r1[0])

xR2 = []
for r2 in allValuesOfR2:
    xR2.append(r2[0])

yR1 = []
for r1 in allValuesOfR1:
    yR1.append(r1[1])

yR2 = []
for r2 in allValuesOfR2:
    yR2.append(r2[1])

labels=c[2]
plt.plot(xCluster1, yCluster1, "x", color = "yellow") 
plt.plot(xCluster2, yCluster2, "x", color = "lightgreen") 

plt.plot(xR1, yR1, "o", color = "orange")
plt.plot(xR2, yR2, "o", color = "darkgreen")

plt.axis("equal") 
plt .show()

# %%
# plot (ii) uppon the dataset

x = c[0] 
y=c[1]

xR1 = []
for r1 in r1AfterClustering:
    xR1.append(r1[0])

xR2 = []
for r2 in r2AfterClustering:
    xR2.append(r2[0])

yR1 = []
for r1 in r1AfterClustering:
    yR1.append(r1[1])

yR2 = []
for r2 in r2AfterClustering:
    yR2.append(r2[1])
    
labels=c[2]
plt.plot(x, y, "x") 
plt.plot(xR1, yR1, "o", color = "orange")
plt.plot(xR2, yR2, "o", color = "lightgreen")

plt.axis("equal") 
plt .show()

# %%
# define parameters, try DIFFERENT ALPHA
alpha = 0.1

# choose random k indexes
# copy data for immutability and transpose to sample complete case
cTCopy = c.T
idexOfPoint1, indexOfPoint2= random.sample(range(len(cTCopy)), k=2)

# define the two k points following the andom indexes
r1 = cTCopy[idexOfPoint1][:2]
r2 = cTCopy[indexOfPoint2][:2]

# initialize two np.arrays to save clusters
cluster1 = []
cluster2 = []

# save all consecutive values of r1 and r2 for the first passage
allValuesOfR1 = []
allValuesOfR2 = []

# implement easy k-means version
for i in range(len(cTCopy)):
    # divide every point in coordinates and label
    coordinate = cTCopy[i][:2]
    trueClusterLabel = cTCopy[i][2]

    # get distance to both k
    distanceToR1 = getEuclideanDistance(r1[0],r1[1], coordinate[0], coordinate[1])
    distanceToR2 = getEuclideanDistance(r2[0],r2[1], coordinate[0], coordinate[1])

    

    # append to cluster of k to which point is closer, swiftly adjust k in position
    if distanceToR1 < distanceToR2:
        allValuesOfR1.append(r1)
        cluster1.append([*coordinate, trueClusterLabel])
        r1 = (1-alpha)*r1+alpha*coordinate
    else:
        allValuesOfR2.append(r2)
        cluster2.append([*coordinate, trueClusterLabel])
        r2 = (1-alpha)*r2+alpha*coordinate

# plot (i) uppon the dataset and also include final clustering of round one

xCluster1 = []
for dataPoint in cluster1:
    xCluster1.append(dataPoint[0])

yCluster1 = []
for dataPoint in cluster1:
    yCluster1.append(dataPoint[1])

xCluster2 = []
for dataPoint in cluster2:
    xCluster2.append(dataPoint[0])

yCluster2 = []
for dataPoint in cluster2:
    yCluster2.append(dataPoint[1])


xR1 = []
for r1 in allValuesOfR1:
    xR1.append(r1[0])

xR2 = []
for r2 in allValuesOfR2:
    xR2.append(r2[0])

yR1 = []
for r1 in allValuesOfR1:
    yR1.append(r1[1])

yR2 = []
for r2 in allValuesOfR2:
    yR2.append(r2[1])

labels=c[2]
plt.plot(xCluster1, yCluster1, "x", color = "yellow") 
plt.plot(xCluster2, yCluster2, "x", color = "lightgreen") 

plt.plot(xR1, yR1, "o", color = "orange")
plt.plot(xR2, yR2, "o", color = "darkgreen")

plt.axis("equal") 
plt .show()

# %%
# (ii) the values of r1 and r2 at the end of each passage. Try DIFFERENT NUMBER OF EPOCHS

# define parameters
alpha = 0.00001

# choose random k indexes
# copy data for immutability and transpose to sample complete case
cTCopy = c.T
idexOfPoint1, indexOfPoint2= random.sample(range(len(cTCopy)), k=2)

# define the two k points following the andom indexes
r1 = cTCopy[idexOfPoint1][:2]
r2 = cTCopy[indexOfPoint2][:2]

# initialize two np.arrays to save clusters
cluster1 = []
cluster2 = []

# initialize lists to store final r1 and r2 values
r1AfterClustering = []
r2AfterClustering = []

# repeat for 10 times, EPOCHS:
for i in range(1000):

    # initialize two np.arrays to save final clusters
    cluster1 = []
    cluster2 = []

    # implement easy k-means version
    for i in range(len(cTCopy)):
        # divide every point in coordinates and label
        coordinate = cTCopy[i][:2]
        trueClusterLabel = cTCopy[i][2]

        # get distance to both k
        distanceToR1 = getEuclideanDistance(r1[0],r1[1], coordinate[0], coordinate[1])
        distanceToR2 = getEuclideanDistance(r2[0],r2[1], coordinate[0], coordinate[1])

        # append to cluster of k to which point is closer, swiftly adjust k in position
        if distanceToR1 < distanceToR2:
            cluster1.append([*coordinate, trueClusterLabel])
            r1 = (1-alpha)*r1+alpha*coordinate
        else:
            cluster2.append([*coordinate, trueClusterLabel])
            r2 = (1-alpha)*r2+alpha*coordinate


    r1AfterClustering.append(r1)
    r2AfterClustering.append(r2)

# plot (ii) uppon the dataset

xCluster1 = []
for dataPoint in cluster1:
    xCluster1.append(dataPoint[0])

yCluster1 = []
for dataPoint in cluster1:
    yCluster1.append(dataPoint[1])

xCluster2 = []
for dataPoint in cluster2:
    xCluster2.append(dataPoint[0])

yCluster2 = []
for dataPoint in cluster2:
    yCluster2.append(dataPoint[1])

xR1 = []
for r1 in r1AfterClustering:
    xR1.append(r1[0])

xR2 = []
for r2 in r2AfterClustering:
    xR2.append(r2[0])

yR1 = []
for r1 in r1AfterClustering:
    yR1.append(r1[1])

yR2 = []
for r2 in r2AfterClustering:
    yR2.append(r2[1])
    
labels=c[2]
plt.plot(xCluster1, yCluster1, "x", color = "yellow") 
plt.plot(xCluster2, yCluster2, "x", color = "lightgreen") 
plt.plot(xR1, yR1, "o", color = "orange")
plt.plot(xR2, yR2, "o", color = "darkgreen")

plt.axis("equal") 
plt .show()

# %% [markdown]
# #### What effect does changing the parameters alpha and the number of epochs have?
#
# After trying out multiple values of alpha and number of epochs, we can say that in both cases, a higher value leads to more movement of k1 and k2. The clusters adapt and change more and faster. Changing the alpha to a bigger number seems to have a stronger corrective effect that changing the epochs to a higher repetition.
#
# When we increase alpha to a high value (e.g. 0.1) the points are not changing in between epochs any more because the movement is the same in all circuits. This is because we loop through the data set in the same order each passage.
#
# Also, if we chose suitable parameter values for alpha and epochs (big enough alpha, enough epochs) we will eventually find that the centroids converge to the true cluster means (since that is the definition of a mean).

# %% [markdown]
# ### Exercise 1.4
#
#  Instead of changing the value of the representatives for each example, accumulate the values of the difference (x − r) and change the value only when all examples have been observed. Accumulate only for the closest representative in each iteration.
#
#     for all x do
#         d ← d + (x − r)
#     end for
#         r ← r + (α/n_examples) ∗ d

# %%
# define parameters
alpha = 1

# choose random k indexes
# copy data for immutability and transpose to sample complete case
cTCopy = c.T
idexOfPoint1, indexOfPoint2= random.sample(range(len(cTCopy)), k=2)

# define the two k points following the random indexes
r1 = cTCopy[idexOfPoint1][:2]
r2 = cTCopy[indexOfPoint2][:2]
r1End = None
r2End = None


allR1 = np.array([r1]).reshape(1, -1) # reshape so that it has one row and (-1) in advance decided number columns (according to number columns of r1)
allR2 = np.array([r2]).reshape(1, -1)


# loop mulitple rounds, epochs:
for i in range(100):

    # from the second round on (i.e., when r2End != None) assign r1 and r2 the new values
    if r1End is None:
        pass
    else:
        r1 = r1End

    if r2End is None:
        pass
    else:
        r2 = r2End
    
    # initialize two np.arrays to save clusters
    cluster1 = []
    cluster2 = []

    # save all consecutive values of r1 and r2 for the first passage
    allValuesOfR1 = []
    allValuesOfR2 = []

    # save total distances
    d1 = np.array([0,0])
    d2 = np.array([0,0])

    # implement second k-means version
    for i in range(len(cTCopy)):
        # divide every point in coordinates and label
        coordinate = cTCopy[i][:2]
        trueClusterLabel = cTCopy[i][2]

        # get distance to both k
        distanceToR1 = getEuclideanDistance(r1[0],r1[1], coordinate[0], coordinate[1])
        distanceToR2 = getEuclideanDistance(r2[0],r2[1], coordinate[0], coordinate[1])

        # append to cluster of k to which point is closer
        if distanceToR1 < distanceToR2:
            cluster1.append([*coordinate, trueClusterLabel])
            d1 = d1 +(coordinate - r1)
        else:
            cluster2.append([*coordinate, trueClusterLabel])
            d2 = d2 +(coordinate - r2)
    # only now change coordinates of r1 and r2
    r1End = r1 + (alpha/len(cluster1))*d1
    r2End = r2 + (alpha/len(cluster2))*d2

    # append all new values for k1, k2
    allR1 = np.append(allR1, r1End.reshape(1, -1), axis=0)
    allR2 = np.append(allR2, r2End.reshape(1, -1), axis=0)


#allR1

# %% [markdown]
# ### Exercise 1.5
#  Plot the consecutive positions of r1 and r2 and compare with the plot in exercise 1.
#
# What do you observe?

# %%
# plot the consecutive positions of r1 and r2 uppon the dataset and also include final clustering of round one

xCluster1 = []
for dataPoint in cluster1:
    xCluster1.append(dataPoint[0])

yCluster1 = []
for dataPoint in cluster1:
    yCluster1.append(dataPoint[1])

xCluster2 = []
for dataPoint in cluster2:
    xCluster2.append(dataPoint[0])

yCluster2 = []
for dataPoint in cluster2:
    yCluster2.append(dataPoint[1])


xR1 = allR1[:, 0]

xR2 = allR2[:, 0]

yR1 = allR1[:, 1]

yR2 = allR2[:, 1]

plt.plot(xCluster1, yCluster1, "x", color = "yellow") 
plt.plot(xCluster2, yCluster2, "x", color = "lightgreen") 

plt.plot(xR1, yR1, "o", color = "orange")
plt.plot(xR2, yR2, "o", color = "darkgreen")

plt.axis("equal") 
plt .show()

# %% [markdown]
# ### What do you observe?
#
# Again the movement of r1, r2 are dependent on their random first value and the values of alpha and epoche.
# However, the movement of r1, r2 seems to be more targeted and does not randomly jump here and there depending on which random point was classified just now. If we would set epoche to (move until no change between r1 and r1End and r2 and r2End) the final and mainly correct clustering could be achieved.
#
# Overall, this k-means version works faster and more reliable.

# %% [markdown]
# ### Exercise 1.6
#
# Plot with different colors:
#
# - color 1 – points closer to r1 labeled 1;
# - color 2 – points closer to r1 labeled 2;
# - color 3 – points closer to r2 labeled 1;
# - color 4 – points closer to r2 labeled 2.
#
# What do you observe?

# %%
xCluster1Correct = []
xCluster1False = []

for dataPoint in cluster1:
    if dataPoint[2] == 1:
        xCluster1Correct.append(dataPoint[0])
    else: 
        xCluster1False.append(dataPoint[0])

yCluster1Correct = []
yCluster1False = []

for dataPoint in cluster1:
    if dataPoint[2] == 1:
        yCluster1Correct.append(dataPoint[1])
    else: 
        yCluster1False.append(dataPoint[1])



xCluster2Correct = []
xCluster2False = []

for dataPoint in cluster2:
    if dataPoint[2] == 2:
        xCluster2Correct.append(dataPoint[0])
    else: 
        xCluster2False.append(dataPoint[0])

yCluster2Correct = []
yCluster2False = []

for dataPoint in cluster2:
    if dataPoint[2] == 2:
        yCluster2Correct.append(dataPoint[1])
    else: 
        yCluster2False.append(dataPoint[1])



xR1 = allR1[:, 0]

xR2 = allR2[:, 0]

yR1 = allR1[:, 1]

yR2 = allR2[:, 1]

plt.plot(xCluster1Correct, yCluster1Correct, "x", color = "yellow") 
plt.plot(xCluster2Correct, yCluster2Correct, "x", color = "lightgreen") 
plt.plot(xCluster1False, yCluster1False, "x", color = "pink") 
plt.plot(xCluster2False, yCluster2False, "x", color = "red") 

plt.plot(xR1, yR1, "o", color = "orange")
plt.plot(xR2, yR2, "o", color = "darkgreen")

plt.axis("equal") 
plt .show()

# %% [markdown]
# #### What do we observe?
#
# since we define the random starting points randomly, we cannot be sure that we have one from each cluster and therefore, when they each move to one of the clusters (since we named the clusters in advance) it is possible, that the naming does not give the right expression in the end.
#
# To fix that, we include a check where we compute the distance between the actual cluster center and our calculated centroids in order to decide which of the clusters is which.
#
# Apart from that, we see that with good aligned parameters, the clusters seem to be mainly correct classified and only a few points on the borders are misclustered.

# %% [markdown]
# ### Exercise 1.7
#
# Repeat the experiment 30 times and plot the final values of r1 and r2 over the dataset. If necessary amplify the viewed area to see the points’ distributions.

# %%
 # define parameters
alpha = 0.01
epochs = 100
# copy data for immutability and transpose to sample complete case
cTCopy = c.T

finalR1 = []
finalR2 = []

for i in range(30):
    # choose random k indexes
    idexOfPoint1, indexOfPoint2= random.sample(range(len(cTCopy)), k=2)

    # define the two k points following the random indexes
    r1 = cTCopy[idexOfPoint1][:2]
    r2 = cTCopy[indexOfPoint2][:2]
    r1End = None
    r2End = None

    # loop mulitple rounds, epochs:
    for i in range(epochs):

        # from the second round on (i.e., when r2End != None) assign r1 and r2 the new values
        if r1End is None:
            pass
        else:
            r1 = r1End

        if r2End is None:
            pass
        else:
            r2 = r2End

        # save total distances
        d1 = np.array([0,0])
        d2 = np.array([0,0])

        # implement second k-means version
        for i in range(len(cTCopy)):
            # divide every point in coordinates and label
            coordinate = cTCopy[i][:2]
            trueClusterLabel = cTCopy[i][2]

            # get distance to both k
            distanceToR1 = getEuclideanDistance(r1[0],r1[1], coordinate[0], coordinate[1])
            distanceToR2 = getEuclideanDistance(r2[0],r2[1], coordinate[0], coordinate[1])

            # append to cluster of k to which point is closer
            if distanceToR1 < distanceToR2:
                d1 = d1 +(coordinate - r1)
            else:
                d2 = d2 +(coordinate - r2)
        # only now change coordinates of r1 and r2
        r1End = r1 + (alpha/len(cluster1))*d1
        r2End = r2 + (alpha/len(cluster2))*d2


    # append all final values for k1, k2
    finalR1.append(r1End)
    finalR2.append(r2End)
    

finalR1 = np.array(finalR1)
finalR2 = np.array(finalR2)

print(len(finalR1))
print(len(finalR2))
# Out:
# 30
# 30

# %%
x = c[0] 
y=c[1]

xFinalR1 = finalR1[:,0]
xFinalR2 = finalR2[:,0]

yFinalR1 = finalR1[:,1]
yFinalR2 = finalR2[:,1]
plt.plot(x, y, "x") 
plt.plot(xFinalR1, yFinalR1, "o", color = "orange")
plt.plot(xFinalR2, yFinalR2, "o", color = "lightgreen")
plt.axis("equal") 
plt .show()

# %%
# amplify to show cluster 1
plt.plot(x, y, "x") 
plt.plot(xFinalR1, yFinalR1, "o", color = "orange")
plt.plot(xFinalR2, yFinalR2, "o", color = "lightgreen")
plt.xlim(-7, 2)
plt.ylim(-7, 2)
plt .show()

# %%
# amplify to show cluster 2
plt.plot(x, y, "x") 
plt.plot(xFinalR1, yFinalR1, "o", color = "orange")
plt.plot(xFinalR2, yFinalR2, "o", color = "lightgreen")
plt.xlim(0, 5)
plt.ylim(0, 5)
plt .show()

# %% [markdown]
# # Exercise 2
#
# Implement a simplified version of agglomerative hierarchical clustering, as proposed in the following algorithm.
#
#     while there are more than two points do
#         Find the closest two points
#         Replace both points by their average
#     end while
#
# Test it on sets of points similar to the ones of the last exercise.

# %%
dataSetInProgress = data.T
len(dataSetInProgress)
dataSetInProgress = dataSetInProgress[:20]
dataSetInProgress
# Out:
# array([[-4.18648723, -6.23521179,  2.        ],
#        [-4.51710136, -4.77343626,  2.        ],
#        [ 2.71680805,  2.14233021,  1.        ],
#        [ 1.64606449,  2.30350752,  1.        ],
#        [ 2.84210015,  2.59179383,  1.        ],
#        [-4.78423754,  2.26703425,  2.        ],
#        [-2.76381161, -5.16864941,  2.        ],
#        [ 2.98709678,  3.70845408,  1.        ],
#        [-2.13529373, -1.2931665 ,  2.        ],
#        [ 3.33020899,  2.26426283,  1.        ],
#        [-2.21866522, -3.86309562,  2.        ],
#        [-1.10722393, -0.62699295,  2.        ],
#        [-4.25042816, -0.38158515,  2.        ],
#        [-3.21306915, -4.16023022,  2.        ],
#        [-5.49977416,  0.04740807,  2.        ],
#        [ 4.25841639,  2.35076047,  1.        ],
#        [ 4.07918137,  3.43038171,  1.        ],
#        [ 3.20801229,  1.40256594,  1.        ],
#        [-3.24219536, -4.76179582,  2.        ],
#        [-5.60104866, -3.49629861,  2.        ]])

# %%
dataSetInProgress = data.T
#dataSetInProgress = np.array([[1,2,1],[1,3,1], [2,3,1], [1,1,1], [3,2,1], [3,3,1], [8,8,2], [9,7,2], [9,9,2], [9,10,2], [8,10,2], [7, 8, 2], [9,8,2]])

mapCombinedHashToDistance = {}
mapHashToPoint = {}

# get all distances between all points
for indexI, i in enumerate(dataSetInProgress):
    mapHashToPoint[str(indexI)] = i
    for indexJ, j in enumerate(dataSetInProgress):
        if not ((i==j).all()):
            distance = getEuclideanDistance(i[0], i[1], j[0], j[1])
            mapCombinedHashToDistance[str(indexI) + "." + str(indexJ)] = distance

# initiate counter to name newPoints according to their index position
mapHashToPointCopy = mapHashToPoint.copy()
newIndexNumber = len(mapHashToPointCopy)


while len(mapHashToPoint)>2:

    # get points with least distance
    IndexesWithShortestDistance = min(mapCombinedHashToDistance, key=mapCombinedHashToDistance.get)
    index1, index2 = IndexesWithShortestDistance.split(".")
    point1 = mapHashToPoint[index1]
    point2 = mapHashToPoint[index2]
    pairWithShortestDistance = np.array([point1, point2])

    # calculate midpoint
    newPointInMIddle = np.mean(pairWithShortestDistance, axis = 0)

    # add newPointInMIddle to dictionary with all points
    indexNewPoint = str(newIndexNumber)
    print(indexNewPoint)
    mapHashToPoint[str(newIndexNumber)] = newPointInMIddle

    # delete two old closest points from dictionary with all points 
    del mapHashToPoint[index1]
    del mapHashToPoint[index2]


    # delete all distances inclusing the two old closest points from dictionary with distances 
    newDict = {}
    for key, value in mapCombinedHashToDistance.items():
        pointIndices = key.split(".")
        if str(index1) == pointIndices[0] or str(index1) == pointIndices[1] or str(index2) == pointIndices[0] or str(index2) == pointIndices[1] :
            continue
        else:
            newDict[key] = value

    mapCombinedHashToDistance = newDict

    # get new distances from each old point to new point and append to dictionaryWithDistances
    for key, value in mapHashToPoint.items():
        if key == indexNewPoint:
            continue
        else:
            distance = getEuclideanDistance(value[0], value[1], newPointInMIddle[0], newPointInMIddle[1])
            mapCombinedHashToDistance[str(key) + "." + indexNewPoint] = distance
    
    # add one to index counter
    newIndexNumber += 1


    print(f"length dictionary with all distancces: {len(mapHashToPoint)}")

print(mapHashToPoint)
# Out:
# 1000
# length dictionary with all distancces: 999
# 1001
# length dictionary with all distancces: 998
# 1002
# length dictionary with all distancces: 997
# 1003
# length dictionary with all distancces: 996
# 1004
# length dictionary with all distancces: 995
# 1005
# length dictionary with all distancces: 994
# 1006
# length dictionary with all distancces: 993
# 1007
# length dictionary with all distancces: 992
# 1008
# length dictionary with all distancces: 991
# 1009
# length dictionary with all distancces: 990
# 1010
# length dictionary with all distancces: 989
# 1011
# length dictionary with all distancces: 988
# 1012
# length dictionary with all distancces: 987
# 1013
# length dictionary with all distancces: 986
# 1014
# length dictionary with all distancces: 985
# 1015
# length dictionary with all distancces: 984
# 1016
# length dictionary with all distancces: 983
# 1017
# length dictionary with all distancces: 982
# 1018
# length dictionary with all distancces: 981
# 1019
# length dictionary with all distancces: 980
# 1020
# length dictionary with all distancces: 979
# 1021
# length dictionary with all distancces: 978
# 1022
# length dictionary with all distancces: 977
# 1023
# length dictionary with all distancces: 976
# 1024
# length dictionary with all distancces: 975
# 1025
# length dictionary with all distancces: 974
# 1026
# length dictionary with all distancces: 973
# 1027
# length dictionary with all distancces: 972
# 1028
# length dictionary with all distancces: 971
# 1029
# length dictionary with all distancces: 970
# 1030
# length dictionary with all distancces: 969
# 1031
# length dictionary with all distancces: 968
# 1032
# length dictionary with all distancces: 967
# 1033
# length dictionary with all distancces: 966
# 1034
# length dictionary with all distancces: 965
# 1035
# length dictionary with all distancces: 964
# 1036
# length dictionary with all distancces: 963
# 1037
# length dictionary with all distancces: 962
# 1038
# length dictionary with all distancces: 961
# 1039
# length dictionary with all distancces: 960
# 1040
# length dictionary with all distancces: 959
# 1041
# length dictionary with all distancces: 958
# 1042
# length dictionary with all distancces: 957
# 1043
# length dictionary with all distancces: 956
# 1044
# length dictionary with all distancces: 955
# 1045
# length dictionary with all distancces: 954
# 1046
# length dictionary with all distancces: 953
# 1047
# length dictionary with all distancces: 952
# 1048
# length dictionary with all distancces: 951
# 1049
# length dictionary with all distancces: 950
# 1050
# length dictionary with all distancces: 949
# 1051
# length dictionary with all distancces: 948
# 1052
# length dictionary with all distancces: 947
# 1053
# length dictionary with all distancces: 946
# 1054
# length dictionary with all distancces: 945
# 1055
# length dictionary with all distancces: 944
# 1056
# length dictionary with all distancces: 943
# 1057
# length dictionary with all distancces: 942
# 1058
# length dictionary with all distancces: 941
# 1059
# length dictionary with all distancces: 940
# 1060
# length dictionary with all distancces: 939
# 1061
# length dictionary with all distancces: 938
# 1062
# length dictionary with all distancces: 937
# 1063
# length dictionary with all distancces: 936
# 1064
# length dictionary with all distancces: 935
# 1065
# length dictionary with all distancces: 934
# 1066
# length dictionary with all distancces: 933
# 1067
# length dictionary with all distancces: 932
# 1068
# length dictionary with all distancces: 931
# 1069
# length dictionary with all distancces: 930
# 1070
# length dictionary with all distancces: 929
# 1071
# length dictionary with all distancces: 928
# 1072
# length dictionary with all distancces: 927
# 1073
# length dictionary with all distancces: 926
# 1074
# length dictionary with all distancces: 925
# 1075
# length dictionary with all distancces: 924
# 1076
# length dictionary with all distancces: 923
# 1077
# length dictionary with all distancces: 922
# 1078
# length dictionary with all distancces: 921
# 1079
# length dictionary with all distancces: 920
# 1080
# length dictionary with all distancces: 919
# 1081
# length dictionary with all distancces: 918
# 1082
# length dictionary with all distancces: 917
# 1083
# length dictionary with all distancces: 916
# 1084
# length dictionary with all distancces: 915
# 1085
# length dictionary with all distancces: 914
# 1086
# length dictionary with all distancces: 913
# 1087
# length dictionary with all distancces: 912
# 1088
# length dictionary with all distancces: 911
# 1089
# length dictionary with all distancces: 910
# 1090
# length dictionary with all distancces: 909
# 1091
# length dictionary with all distancces: 908
# 1092
# length dictionary with all distancces: 907
# 1093
# length dictionary with all distancces: 906
# 1094
# length dictionary with all distancces: 905
# 1095
# length dictionary with all distancces: 904
# 1096
# length dictionary with all distancces: 903
# 1097
# length dictionary with all distancces: 902
# 1098
# length dictionary with all distancces: 901
# 1099
# length dictionary with all distancces: 900
# 1100
# length dictionary with all distancces: 899
# 1101
# length dictionary with all distancces: 898
# 1102
# length dictionary with all distancces: 897
# 1103
# length dictionary with all distancces: 896
# 1104
# length dictionary with all distancces: 895
# 1105
# length dictionary with all distancces: 894
# 1106
# length dictionary with all distancces: 893
# 1107
# length dictionary with all distancces: 892
# 1108
# length dictionary with all distancces: 891
# 1109
# length dictionary with all distancces: 890
# 1110
# length dictionary with all distancces: 889
# 1111
# length dictionary with all distancces: 888
# 1112
# length dictionary with all distancces: 887
# 1113
# length dictionary with all distancces: 886
# 1114
# length dictionary with all distancces: 885
# 1115
# length dictionary with all distancces: 884
# 1116
# length dictionary with all distancces: 883
# 1117
# length dictionary with all distancces: 882
# 1118
# length dictionary with all distancces: 881
# 1119
# length dictionary with all distancces: 880
# 1120
# length dictionary with all distancces: 879
# 1121
# length dictionary with all distancces: 878
# 1122
# length dictionary with all distancces: 877
# 1123
# length dictionary with all distancces: 876
# 1124
# length dictionary with all distancces: 875
# 1125
# length dictionary with all distancces: 874
# 1126
# length dictionary with all distancces: 873
# 1127
# length dictionary with all distancces: 872
# 1128
# length dictionary with all distancces: 871
# 1129
# length dictionary with all distancces: 870
# 1130
# length dictionary with all distancces: 869
# 1131
# length dictionary with all distancces: 868
# 1132
# length dictionary with all distancces: 867
# 1133
# length dictionary with all distancces: 866
# 1134
# length dictionary with all distancces: 865
# 1135
# length dictionary with all distancces: 864
# 1136
# length dictionary with all distancces: 863
# 1137
# length dictionary with all distancces: 862
# 1138
# length dictionary with all distancces: 861
# 1139
# length dictionary with all distancces: 860
# 1140
# length dictionary with all distancces: 859
# 1141
# length dictionary with all distancces: 858
# 1142
# length dictionary with all distancces: 857
# 1143
# length dictionary with all distancces: 856
# 1144
# length dictionary with all distancces: 855
# 1145
# length dictionary with all distancces: 854
# 1146
# length dictionary with all distancces: 853
# 1147
# length dictionary with all distancces: 852
# 1148
# length dictionary with all distancces: 851
# 1149
# length dictionary with all distancces: 850
# 1150
# length dictionary with all distancces: 849
# 1151
# length dictionary with all distancces: 848
# 1152
# length dictionary with all distancces: 847
# 1153
# length dictionary with all distancces: 846
# 1154
# length dictionary with all distancces: 845
# 1155
# length dictionary with all distancces: 844
# 1156
# length dictionary with all distancces: 843
# 1157
# length dictionary with all distancces: 842
# 1158
# length dictionary with all distancces: 841
# 1159
# length dictionary with all distancces: 840
# 1160
# length dictionary with all distancces: 839
# 1161
# length dictionary with all distancces: 838
# 1162
# length dictionary with all distancces: 837
# 1163
# length dictionary with all distancces: 836
# 1164
# length dictionary with all distancces: 835
# 1165
# length dictionary with all distancces: 834
# 1166
# length dictionary with all distancces: 833
# 1167
# length dictionary with all distancces: 832
# 1168
# length dictionary with all distancces: 831
# 1169
# length dictionary with all distancces: 830
# 1170
# length dictionary with all distancces: 829
# 1171
# length dictionary with all distancces: 828
# 1172
# length dictionary with all distancces: 827
# 1173
# length dictionary with all distancces: 826
# 1174
# length dictionary with all distancces: 825
# 1175
# length dictionary with all distancces: 824
# 1176
# length dictionary with all distancces: 823
# 1177
# length dictionary with all distancces: 822
# 1178
# length dictionary with all distancces: 821
# 1179
# length dictionary with all distancces: 820
# 1180
# length dictionary with all distancces: 819
# 1181
# length dictionary with all distancces: 818
# 1182
# length dictionary with all distancces: 817
# 1183
# length dictionary with all distancces: 816
# 1184
# length dictionary with all distancces: 815
# 1185
# length dictionary with all distancces: 814
# 1186
# length dictionary with all distancces: 813
# 1187
# length dictionary with all distancces: 812
# 1188
# length dictionary with all distancces: 811
# 1189
# length dictionary with all distancces: 810
# 1190
# length dictionary with all distancces: 809
# 1191
# length dictionary with all distancces: 808
# 1192
# length dictionary with all distancces: 807
# 1193
# length dictionary with all distancces: 806
# 1194
# length dictionary with all distancces: 805
# 1195
# length dictionary with all distancces: 804
# 1196
# length dictionary with all distancces: 803
# 1197
# length dictionary with all distancces: 802
# 1198
# length dictionary with all distancces: 801
# 1199
# length dictionary with all distancces: 800
# 1200
# length dictionary with all distancces: 799
# 1201
# length dictionary with all distancces: 798
# 1202
# length dictionary with all distancces: 797
# 1203
# length dictionary with all distancces: 796
# 1204
# length dictionary with all distancces: 795
# 1205
# length dictionary with all distancces: 794
# 1206
# length dictionary with all distancces: 793
# 1207
# length dictionary with all distancces: 792
# 1208
# length dictionary with all distancces: 791
# 1209
# length dictionary with all distancces: 790
# 1210
# length dictionary with all distancces: 789
# 1211
# length dictionary with all distancces: 788
# 1212
# length dictionary with all distancces: 787
# 1213
# length dictionary with all distancces: 786
# 1214
# length dictionary with all distancces: 785
# 1215
# length dictionary with all distancces: 784
# 1216
# length dictionary with all distancces: 783
# 1217
# length dictionary with all distancces: 782
# 1218
# length dictionary with all distancces: 781
# 1219
# length dictionary with all distancces: 780
# 1220
# length dictionary with all distancces: 779
# 1221
# length dictionary with all distancces: 778
# 1222
# length dictionary with all distancces: 777
# 1223
# length dictionary with all distancces: 776
# 1224
# length dictionary with all distancces: 775
# 1225
# length dictionary with all distancces: 774
# 1226
# length dictionary with all distancces: 773
# 1227
# length dictionary with all distancces: 772
# 1228
# length dictionary with all distancces: 771
# 1229
# length dictionary with all distancces: 770
# 1230
# length dictionary with all distancces: 769
# 1231
# length dictionary with all distancces: 768
# 1232
# length dictionary with all distancces: 767
# 1233
# length dictionary with all distancces: 766
# 1234
# length dictionary with all distancces: 765
# 1235
# length dictionary with all distancces: 764
# 1236
# length dictionary with all distancces: 763
# 1237
# length dictionary with all distancces: 762
# 1238
# length dictionary with all distancces: 761
# 1239
# length dictionary with all distancces: 760
# 1240
# length dictionary with all distancces: 759
# 1241
# length dictionary with all distancces: 758
# 1242
# length dictionary with all distancces: 757
# 1243
# length dictionary with all distancces: 756
# 1244
# length dictionary with all distancces: 755
# 1245
# length dictionary with all distancces: 754
# 1246
# length dictionary with all distancces: 753
# 1247
# length dictionary with all distancces: 752
# 1248
# length dictionary with all distancces: 751
# 1249
# length dictionary with all distancces: 750
# 1250
# length dictionary with all distancces: 749
# 1251
# length dictionary with all distancces: 748
# 1252
# length dictionary with all distancces: 747
# 1253
# length dictionary with all distancces: 746
# 1254
# length dictionary with all distancces: 745
# 1255
# length dictionary with all distancces: 744
# 1256
# length dictionary with all distancces: 743
# 1257
# length dictionary with all distancces: 742
# 1258
# length dictionary with all distancces: 741
# 1259
# length dictionary with all distancces: 740
# 1260
# length dictionary with all distancces: 739
# 1261
# length dictionary with all distancces: 738
# 1262
# length dictionary with all distancces: 737
# 1263
# length dictionary with all distancces: 736
# 1264
# length dictionary with all distancces: 735
# 1265
# length dictionary with all distancces: 734
# 1266
# length dictionary with all distancces: 733
# 1267
# length dictionary with all distancces: 732
# 1268
# length dictionary with all distancces: 731
# 1269
# length dictionary with all distancces: 730
# 1270
# length dictionary with all distancces: 729
# 1271
# length dictionary with all distancces: 728
# 1272
# length dictionary with all distancces: 727
# 1273
# length dictionary with all distancces: 726
# 1274
# length dictionary with all distancces: 725
# 1275
# length dictionary with all distancces: 724
# 1276
# length dictionary with all distancces: 723
# 1277
# length dictionary with all distancces: 722
# 1278
# length dictionary with all distancces: 721
# 1279
# length dictionary with all distancces: 720
# 1280
# length dictionary with all distancces: 719
# 1281
# length dictionary with all distancces: 718
# 1282
# length dictionary with all distancces: 717
# 1283
# length dictionary with all distancces: 716
# 1284
# length dictionary with all distancces: 715
# 1285
# length dictionary with all distancces: 714
# 1286
# length dictionary with all distancces: 713
# 1287
# length dictionary with all distancces: 712
# 1288
# length dictionary with all distancces: 711
# 1289
# length dictionary with all distancces: 710
# 1290
# length dictionary with all distancces: 709
# 1291
# length dictionary with all distancces: 708
# 1292
# length dictionary with all distancces: 707
# 1293
# length dictionary with all distancces: 706
# 1294
# length dictionary with all distancces: 705
# 1295
# length dictionary with all distancces: 704
# 1296
# length dictionary with all distancces: 703
# 1297
# length dictionary with all distancces: 702
# 1298
# length dictionary with all distancces: 701
# 1299
# length dictionary with all distancces: 700
# 1300
# length dictionary with all distancces: 699
# 1301
# length dictionary with all distancces: 698
# 1302
# length dictionary with all distancces: 697
# 1303
# length dictionary with all distancces: 696
# 1304
# length dictionary with all distancces: 695
# 1305
# length dictionary with all distancces: 694
# 1306
# length dictionary with all distancces: 693
# 1307
# length dictionary with all distancces: 692
# 1308
# length dictionary with all distancces: 691
# 1309
# length dictionary with all distancces: 690
# 1310
# length dictionary with all distancces: 689
# 1311
# length dictionary with all distancces: 688
# 1312
# length dictionary with all distancces: 687
# 1313
# length dictionary with all distancces: 686
# 1314
# length dictionary with all distancces: 685
# 1315
# length dictionary with all distancces: 684
# 1316
# length dictionary with all distancces: 683
# 1317
# length dictionary with all distancces: 682
# 1318
# length dictionary with all distancces: 681
# 1319
# length dictionary with all distancces: 680
# 1320
# length dictionary with all distancces: 679
# 1321
# length dictionary with all distancces: 678
# 1322
# length dictionary with all distancces: 677
# 1323
# length dictionary with all distancces: 676
# 1324
# length dictionary with all distancces: 675
# 1325
# length dictionary with all distancces: 674
# 1326
# length dictionary with all distancces: 673
# 1327
# length dictionary with all distancces: 672
# 1328
# length dictionary with all distancces: 671
# 1329
# length dictionary with all distancces: 670
# 1330
# length dictionary with all distancces: 669
# 1331
# length dictionary with all distancces: 668
# 1332
# length dictionary with all distancces: 667
# 1333
# length dictionary with all distancces: 666
# 1334
# length dictionary with all distancces: 665
# 1335
# length dictionary with all distancces: 664
# 1336
# length dictionary with all distancces: 663
# 1337
# length dictionary with all distancces: 662
# 1338
# length dictionary with all distancces: 661
# 1339
# length dictionary with all distancces: 660
# 1340
# length dictionary with all distancces: 659
# 1341
# length dictionary with all distancces: 658
# 1342
# length dictionary with all distancces: 657
# 1343
# length dictionary with all distancces: 656
# 1344
# length dictionary with all distancces: 655
# 1345
# length dictionary with all distancces: 654
# 1346
# length dictionary with all distancces: 653
# 1347
# length dictionary with all distancces: 652
# 1348
# length dictionary with all distancces: 651
# 1349
# length dictionary with all distancces: 650
# 1350
# length dictionary with all distancces: 649
# 1351
# length dictionary with all distancces: 648
# 1352
# length dictionary with all distancces: 647
# 1353
# length dictionary with all distancces: 646
# 1354
# length dictionary with all distancces: 645
# 1355
# length dictionary with all distancces: 644
# 1356
# length dictionary with all distancces: 643
# 1357
# length dictionary with all distancces: 642
# 1358
# length dictionary with all distancces: 641
# 1359
# length dictionary with all distancces: 640
# 1360
# length dictionary with all distancces: 639
# 1361
# length dictionary with all distancces: 638
# 1362
# length dictionary with all distancces: 637
# 1363
# length dictionary with all distancces: 636
# 1364
# length dictionary with all distancces: 635
# 1365
# length dictionary with all distancces: 634
# 1366
# length dictionary with all distancces: 633
# 1367
# length dictionary with all distancces: 632
# 1368
# length dictionary with all distancces: 631
# 1369
# length dictionary with all distancces: 630
# 1370
# length dictionary with all distancces: 629
# 1371
# length dictionary with all distancces: 628
# 1372
# length dictionary with all distancces: 627
# 1373
# length dictionary with all distancces: 626
# 1374
# length dictionary with all distancces: 625
# 1375
# length dictionary with all distancces: 624
# 1376
# length dictionary with all distancces: 623
# 1377
# length dictionary with all distancces: 622
# 1378
# length dictionary with all distancces: 621
# 1379
# length dictionary with all distancces: 620
# 1380
# length dictionary with all distancces: 619
# 1381
# length dictionary with all distancces: 618
# 1382
# length dictionary with all distancces: 617
# 1383
# length dictionary with all distancces: 616
# 1384
# length dictionary with all distancces: 615
# 1385
# length dictionary with all distancces: 614
# 1386
# length dictionary with all distancces: 613
# 1387
# length dictionary with all distancces: 612
# 1388
# length dictionary with all distancces: 611
# 1389
# length dictionary with all distancces: 610
# 1390
# length dictionary with all distancces: 609
# 1391
# length dictionary with all distancces: 608
# 1392
# length dictionary with all distancces: 607
# 1393
# length dictionary with all distancces: 606
# 1394
# length dictionary with all distancces: 605
# 1395
# length dictionary with all distancces: 604
# 1396
# length dictionary with all distancces: 603
# 1397
# length dictionary with all distancces: 602
# 1398
# length dictionary with all distancces: 601
# 1399
# length dictionary with all distancces: 600
# 1400
# length dictionary with all distancces: 599
# 1401
# length dictionary with all distancces: 598
# 1402
# length dictionary with all distancces: 597
# 1403
# length dictionary with all distancces: 596
# 1404
# length dictionary with all distancces: 595
# 1405
# length dictionary with all distancces: 594
# 1406
# length dictionary with all distancces: 593
# 1407
# length dictionary with all distancces: 592
# 1408
# length dictionary with all distancces: 591
# 1409
# length dictionary with all distancces: 590
# 1410
# length dictionary with all distancces: 589
# 1411
# length dictionary with all distancces: 588
# 1412
# length dictionary with all distancces: 587
# 1413
# length dictionary with all distancces: 586
# 1414
# length dictionary with all distancces: 585
# 1415
# length dictionary with all distancces: 584
# 1416
# length dictionary with all distancces: 583
# 1417
# length dictionary with all distancces: 582
# 1418
# length dictionary with all distancces: 581
# 1419
# length dictionary with all distancces: 580
# 1420
# length dictionary with all distancces: 579
# 1421
# length dictionary with all distancces: 578
# 1422
# length dictionary with all distancces: 577
# 1423
# length dictionary with all distancces: 576
# 1424
# length dictionary with all distancces: 575
# 1425
# length dictionary with all distancces: 574
# 1426
# length dictionary with all distancces: 573
# 1427
# length dictionary with all distancces: 572
# 1428
# length dictionary with all distancces: 571
# 1429
# length dictionary with all distancces: 570
# 1430
# length dictionary with all distancces: 569
# 1431
# length dictionary with all distancces: 568
# 1432
# length dictionary with all distancces: 567
# 1433
# length dictionary with all distancces: 566
# 1434
# length dictionary with all distancces: 565
# 1435
# length dictionary with all distancces: 564
# 1436
# length dictionary with all distancces: 563
# 1437
# length dictionary with all distancces: 562
# 1438
# length dictionary with all distancces: 561
# 1439
# length dictionary with all distancces: 560
# 1440
# length dictionary with all distancces: 559
# 1441
# length dictionary with all distancces: 558
# 1442
# length dictionary with all distancces: 557
# 1443
# length dictionary with all distancces: 556
# 1444
# length dictionary with all distancces: 555
# 1445
# length dictionary with all distancces: 554
# 1446
# length dictionary with all distancces: 553
# 1447
# length dictionary with all distancces: 552
# 1448
# length dictionary with all distancces: 551
# 1449
# length dictionary with all distancces: 550
# 1450
# length dictionary with all distancces: 549
# 1451
# length dictionary with all distancces: 548
# 1452
# length dictionary with all distancces: 547
# 1453
# length dictionary with all distancces: 546
# 1454
# length dictionary with all distancces: 545
# 1455
# length dictionary with all distancces: 544
# 1456
# length dictionary with all distancces: 543
# 1457
# length dictionary with all distancces: 542
# 1458
# length dictionary with all distancces: 541
# 1459
# length dictionary with all distancces: 540
# 1460
# length dictionary with all distancces: 539
# 1461
# length dictionary with all distancces: 538
# 1462
# length dictionary with all distancces: 537
# 1463
# length dictionary with all distancces: 536
# 1464
# length dictionary with all distancces: 535
# 1465
# length dictionary with all distancces: 534
# 1466
# length dictionary with all distancces: 533
# 1467
# length dictionary with all distancces: 532
# 1468
# length dictionary with all distancces: 531
# 1469
# length dictionary with all distancces: 530
# 1470
# length dictionary with all distancces: 529
# 1471
# length dictionary with all distancces: 528
# 1472
# length dictionary with all distancces: 527
# 1473
# length dictionary with all distancces: 526
# 1474
# length dictionary with all distancces: 525
# 1475
# length dictionary with all distancces: 524
# 1476
# length dictionary with all distancces: 523
# 1477
# length dictionary with all distancces: 522
# 1478
# length dictionary with all distancces: 521
# 1479
# length dictionary with all distancces: 520
# 1480
# length dictionary with all distancces: 519
# 1481
# length dictionary with all distancces: 518
# 1482
# length dictionary with all distancces: 517
# 1483
# length dictionary with all distancces: 516
# 1484
# length dictionary with all distancces: 515
# 1485
# length dictionary with all distancces: 514
# 1486
# length dictionary with all distancces: 513
# 1487
# length dictionary with all distancces: 512
# 1488
# length dictionary with all distancces: 511
# 1489
# length dictionary with all distancces: 510
# 1490
# length dictionary with all distancces: 509
# 1491
# length dictionary with all distancces: 508
# 1492
# length dictionary with all distancces: 507
# 1493
# length dictionary with all distancces: 506
# 1494
# length dictionary with all distancces: 505
# 1495
# length dictionary with all distancces: 504
# 1496
# length dictionary with all distancces: 503
# 1497
# length dictionary with all distancces: 502
# 1498
# length dictionary with all distancces: 501
# 1499
# length dictionary with all distancces: 500
# 1500
# length dictionary with all distancces: 499
# 1501
# length dictionary with all distancces: 498
# 1502
# length dictionary with all distancces: 497
# 1503
# length dictionary with all distancces: 496
# 1504
# length dictionary with all distancces: 495
# 1505
# length dictionary with all distancces: 494
# 1506
# length dictionary with all distancces: 493
# 1507
# length dictionary with all distancces: 492
# 1508
# length dictionary with all distancces: 491
# 1509
# length dictionary with all distancces: 490
# 1510
# length dictionary with all distancces: 489
# 1511
# length dictionary with all distancces: 488
# 1512
# length dictionary with all distancces: 487
# 1513
# length dictionary with all distancces: 486
# 1514
# length dictionary with all distancces: 485
# 1515
# length dictionary with all distancces: 484
# 1516
# length dictionary with all distancces: 483
# 1517
# length dictionary with all distancces: 482
# 1518
# length dictionary with all distancces: 481
# 1519
# length dictionary with all distancces: 480
# 1520
# length dictionary with all distancces: 479
# 1521
# length dictionary with all distancces: 478
# 1522
# length dictionary with all distancces: 477
# 1523
# length dictionary with all distancces: 476
# 1524
# length dictionary with all distancces: 475
# 1525
# length dictionary with all distancces: 474
# 1526
# length dictionary with all distancces: 473
# 1527
# length dictionary with all distancces: 472
# 1528
# length dictionary with all distancces: 471
# 1529
# length dictionary with all distancces: 470
# 1530
# length dictionary with all distancces: 469
# 1531
# length dictionary with all distancces: 468
# 1532
# length dictionary with all distancces: 467
# 1533
# length dictionary with all distancces: 466
# 1534
# length dictionary with all distancces: 465
# 1535
# length dictionary with all distancces: 464
# 1536
# length dictionary with all distancces: 463
# 1537
# length dictionary with all distancces: 462
# 1538
# length dictionary with all distancces: 461
# 1539
# length dictionary with all distancces: 460
# 1540
# length dictionary with all distancces: 459
# 1541
# length dictionary with all distancces: 458
# 1542
# length dictionary with all distancces: 457
# 1543
# length dictionary with all distancces: 456
# 1544
# length dictionary with all distancces: 455
# 1545
# length dictionary with all distancces: 454
# 1546
# length dictionary with all distancces: 453
# 1547
# length dictionary with all distancces: 452
# 1548
# length dictionary with all distancces: 451
# 1549
# length dictionary with all distancces: 450
# 1550
# length dictionary with all distancces: 449
# 1551
# length dictionary with all distancces: 448
# 1552
# length dictionary with all distancces: 447
# 1553
# length dictionary with all distancces: 446
# 1554
# length dictionary with all distancces: 445
# 1555
# length dictionary with all distancces: 444
# 1556
# length dictionary with all distancces: 443
# 1557
# length dictionary with all distancces: 442
# 1558
# length dictionary with all distancces: 441
# 1559
# length dictionary with all distancces: 440
# 1560
# length dictionary with all distancces: 439
# 1561
# length dictionary with all distancces: 438
# 1562
# length dictionary with all distancces: 437
# 1563
# length dictionary with all distancces: 436
# 1564
# length dictionary with all distancces: 435
# 1565
# length dictionary with all distancces: 434
# 1566
# length dictionary with all distancces: 433
# 1567
# length dictionary with all distancces: 432
# 1568
# length dictionary with all distancces: 431
# 1569
# length dictionary with all distancces: 430
# 1570
# length dictionary with all distancces: 429
# 1571
# length dictionary with all distancces: 428
# 1572
# length dictionary with all distancces: 427
# 1573
# length dictionary with all distancces: 426
# 1574
# length dictionary with all distancces: 425
# 1575
# length dictionary with all distancces: 424
# 1576
# length dictionary with all distancces: 423
# 1577
# length dictionary with all distancces: 422
# 1578
# length dictionary with all distancces: 421
# 1579
# length dictionary with all distancces: 420
# 1580
# length dictionary with all distancces: 419
# 1581
# length dictionary with all distancces: 418
# 1582
# length dictionary with all distancces: 417
# 1583
# length dictionary with all distancces: 416
# 1584
# length dictionary with all distancces: 415
# 1585
# length dictionary with all distancces: 414
# 1586
# length dictionary with all distancces: 413
# 1587
# length dictionary with all distancces: 412
# 1588
# length dictionary with all distancces: 411
# 1589
# length dictionary with all distancces: 410
# 1590
# length dictionary with all distancces: 409
# 1591
# length dictionary with all distancces: 408
# 1592
# length dictionary with all distancces: 407
# 1593
# length dictionary with all distancces: 406
# 1594
# length dictionary with all distancces: 405
# 1595
# length dictionary with all distancces: 404
# 1596
# length dictionary with all distancces: 403
# 1597
# length dictionary with all distancces: 402
# 1598
# length dictionary with all distancces: 401
# 1599
# length dictionary with all distancces: 400
# 1600
# length dictionary with all distancces: 399
# 1601
# length dictionary with all distancces: 398
# 1602
# length dictionary with all distancces: 397
# 1603
# length dictionary with all distancces: 396
# 1604
# length dictionary with all distancces: 395
# 1605
# length dictionary with all distancces: 394
# 1606
# length dictionary with all distancces: 393
# 1607
# length dictionary with all distancces: 392
# 1608
# length dictionary with all distancces: 391
# 1609
# length dictionary with all distancces: 390
# 1610
# length dictionary with all distancces: 389
# 1611
# length dictionary with all distancces: 388
# 1612
# length dictionary with all distancces: 387
# 1613
# length dictionary with all distancces: 386
# 1614
# length dictionary with all distancces: 385
# 1615
# length dictionary with all distancces: 384
# 1616
# length dictionary with all distancces: 383
# 1617
# length dictionary with all distancces: 382
# 1618
# length dictionary with all distancces: 381
# 1619
# length dictionary with all distancces: 380
# 1620
# length dictionary with all distancces: 379
# 1621
# length dictionary with all distancces: 378
# 1622
# length dictionary with all distancces: 377
# 1623
# length dictionary with all distancces: 376
# 1624
# length dictionary with all distancces: 375
# 1625
# length dictionary with all distancces: 374
# 1626
# length dictionary with all distancces: 373
# 1627
# length dictionary with all distancces: 372
# 1628
# length dictionary with all distancces: 371
# 1629
# length dictionary with all distancces: 370
# 1630
# length dictionary with all distancces: 369
# 1631
# length dictionary with all distancces: 368
# 1632
# length dictionary with all distancces: 367
# 1633
# length dictionary with all distancces: 366
# 1634
# length dictionary with all distancces: 365
# 1635
# length dictionary with all distancces: 364
# 1636
# length dictionary with all distancces: 363
# 1637
# length dictionary with all distancces: 362
# 1638
# length dictionary with all distancces: 361
# 1639
# length dictionary with all distancces: 360
# 1640
# length dictionary with all distancces: 359
# 1641
# length dictionary with all distancces: 358
# 1642
# length dictionary with all distancces: 357
# 1643
# length dictionary with all distancces: 356
# 1644
# length dictionary with all distancces: 355
# 1645
# length dictionary with all distancces: 354
# 1646
# length dictionary with all distancces: 353
# 1647
# length dictionary with all distancces: 352
# 1648
# length dictionary with all distancces: 351
# 1649
# length dictionary with all distancces: 350
# 1650
# length dictionary with all distancces: 349
# 1651
# length dictionary with all distancces: 348
# 1652
# length dictionary with all distancces: 347
# 1653
# length dictionary with all distancces: 346
# 1654
# length dictionary with all distancces: 345
# 1655
# length dictionary with all distancces: 344
# 1656
# length dictionary with all distancces: 343
# 1657
# length dictionary with all distancces: 342
# 1658
# length dictionary with all distancces: 341
# 1659
# length dictionary with all distancces: 340
# 1660
# length dictionary with all distancces: 339
# 1661
# length dictionary with all distancces: 338
# 1662
# length dictionary with all distancces: 337
# 1663
# length dictionary with all distancces: 336
# 1664
# length dictionary with all distancces: 335
# 1665
# length dictionary with all distancces: 334
# 1666
# length dictionary with all distancces: 333
# 1667
# length dictionary with all distancces: 332
# 1668
# length dictionary with all distancces: 331
# 1669
# length dictionary with all distancces: 330
# 1670
# length dictionary with all distancces: 329
# 1671
# length dictionary with all distancces: 328
# 1672
# length dictionary with all distancces: 327
# 1673
# length dictionary with all distancces: 326
# 1674
# length dictionary with all distancces: 325
# 1675
# length dictionary with all distancces: 324
# 1676
# length dictionary with all distancces: 323
# 1677
# length dictionary with all distancces: 322
# 1678
# length dictionary with all distancces: 321
# 1679
# length dictionary with all distancces: 320
# 1680
# length dictionary with all distancces: 319
# 1681
# length dictionary with all distancces: 318
# 1682
# length dictionary with all distancces: 317
# 1683
# length dictionary with all distancces: 316
# 1684
# length dictionary with all distancces: 315
# 1685
# length dictionary with all distancces: 314
# 1686
# length dictionary with all distancces: 313
# 1687
# length dictionary with all distancces: 312
# 1688
# length dictionary with all distancces: 311
# 1689
# length dictionary with all distancces: 310
# 1690
# length dictionary with all distancces: 309
# 1691
# length dictionary with all distancces: 308
# 1692
# length dictionary with all distancces: 307
# 1693
# length dictionary with all distancces: 306
# 1694
# length dictionary with all distancces: 305
# 1695
# length dictionary with all distancces: 304
# 1696
# length dictionary with all distancces: 303
# 1697
# length dictionary with all distancces: 302
# 1698
# length dictionary with all distancces: 301
# 1699
# length dictionary with all distancces: 300
# 1700
# length dictionary with all distancces: 299
# 1701
# length dictionary with all distancces: 298
# 1702
# length dictionary with all distancces: 297
# 1703
# length dictionary with all distancces: 296
# 1704
# length dictionary with all distancces: 295
# 1705
# length dictionary with all distancces: 294
# 1706
# length dictionary with all distancces: 293
# 1707
# length dictionary with all distancces: 292
# 1708
# length dictionary with all distancces: 291
# 1709
# length dictionary with all distancces: 290
# 1710
# length dictionary with all distancces: 289
# 1711
# length dictionary with all distancces: 288
# 1712
# length dictionary with all distancces: 287
# 1713
# length dictionary with all distancces: 286
# 1714
# length dictionary with all distancces: 285
# 1715
# length dictionary with all distancces: 284
# 1716
# length dictionary with all distancces: 283
# 1717
# length dictionary with all distancces: 282
# 1718
# length dictionary with all distancces: 281
# 1719
# length dictionary with all distancces: 280
# 1720
# length dictionary with all distancces: 279
# 1721
# length dictionary with all distancces: 278
# 1722
# length dictionary with all distancces: 277
# 1723
# length dictionary with all distancces: 276
# 1724
# length dictionary with all distancces: 275
# 1725
# length dictionary with all distancces: 274
# 1726
# length dictionary with all distancces: 273
# 1727
# length dictionary with all distancces: 272
# 1728
# length dictionary with all distancces: 271
# 1729
# length dictionary with all distancces: 270
# 1730
# length dictionary with all distancces: 269
# 1731
# length dictionary with all distancces: 268
# 1732
# length dictionary with all distancces: 267
# 1733
# length dictionary with all distancces: 266
# 1734
# length dictionary with all distancces: 265
# 1735
# length dictionary with all distancces: 264
# 1736
# length dictionary with all distancces: 263
# 1737
# length dictionary with all distancces: 262
# 1738
# length dictionary with all distancces: 261
# 1739
# length dictionary with all distancces: 260
# 1740
# length dictionary with all distancces: 259
# 1741
# length dictionary with all distancces: 258
# 1742
# length dictionary with all distancces: 257
# 1743
# length dictionary with all distancces: 256
# 1744
# length dictionary with all distancces: 255
# 1745
# length dictionary with all distancces: 254
# 1746
# length dictionary with all distancces: 253
# 1747
# length dictionary with all distancces: 252
# 1748
# length dictionary with all distancces: 251
# 1749
# length dictionary with all distancces: 250
# 1750
# length dictionary with all distancces: 249
# 1751
# length dictionary with all distancces: 248
# 1752
# length dictionary with all distancces: 247
# 1753
# length dictionary with all distancces: 246
# 1754
# length dictionary with all distancces: 245
# 1755
# length dictionary with all distancces: 244
# 1756
# length dictionary with all distancces: 243
# 1757
# length dictionary with all distancces: 242
# 1758
# length dictionary with all distancces: 241
# 1759
# length dictionary with all distancces: 240
# 1760
# length dictionary with all distancces: 239
# 1761
# length dictionary with all distancces: 238
# 1762
# length dictionary with all distancces: 237
# 1763
# length dictionary with all distancces: 236
# 1764
# length dictionary with all distancces: 235
# 1765
# length dictionary with all distancces: 234
# 1766
# length dictionary with all distancces: 233
# 1767
# length dictionary with all distancces: 232
# 1768
# length dictionary with all distancces: 231
# 1769
# length dictionary with all distancces: 230
# 1770
# length dictionary with all distancces: 229
# 1771
# length dictionary with all distancces: 228
# 1772
# length dictionary with all distancces: 227
# 1773
# length dictionary with all distancces: 226
# 1774
# length dictionary with all distancces: 225
# 1775
# length dictionary with all distancces: 224
# 1776
# length dictionary with all distancces: 223
# 1777
# length dictionary with all distancces: 222
# 1778
# length dictionary with all distancces: 221
# 1779
# length dictionary with all distancces: 220
# 1780
# length dictionary with all distancces: 219
# 1781
# length dictionary with all distancces: 218
# 1782
# length dictionary with all distancces: 217
# 1783
# length dictionary with all distancces: 216
# 1784
# length dictionary with all distancces: 215
# 1785
# length dictionary with all distancces: 214
# 1786
# length dictionary with all distancces: 213
# 1787
# length dictionary with all distancces: 212
# 1788
# length dictionary with all distancces: 211
# 1789
# length dictionary with all distancces: 210
# 1790
# length dictionary with all distancces: 209
# 1791
# length dictionary with all distancces: 208
# 1792
# length dictionary with all distancces: 207
# 1793
# length dictionary with all distancces: 206
# 1794
# length dictionary with all distancces: 205
# 1795
# length dictionary with all distancces: 204
# 1796
# length dictionary with all distancces: 203
# 1797
# length dictionary with all distancces: 202
# 1798
# length dictionary with all distancces: 201
# 1799
# length dictionary with all distancces: 200
# 1800
# length dictionary with all distancces: 199
# 1801
# length dictionary with all distancces: 198
# 1802
# length dictionary with all distancces: 197
# 1803
# length dictionary with all distancces: 196
# 1804
# length dictionary with all distancces: 195
# 1805
# length dictionary with all distancces: 194
# 1806
# length dictionary with all distancces: 193
# 1807
# length dictionary with all distancces: 192
# 1808
# length dictionary with all distancces: 191
# 1809
# length dictionary with all distancces: 190
# 1810
# length dictionary with all distancces: 189
# 1811
# length dictionary with all distancces: 188
# 1812
# length dictionary with all distancces: 187
# 1813
# length dictionary with all distancces: 186
# 1814
# length dictionary with all distancces: 185
# 1815
# length dictionary with all distancces: 184
# 1816
# length dictionary with all distancces: 183
# 1817
# length dictionary with all distancces: 182
# 1818
# length dictionary with all distancces: 181
# 1819
# length dictionary with all distancces: 180
# 1820
# length dictionary with all distancces: 179
# 1821
# length dictionary with all distancces: 178
# 1822
# length dictionary with all distancces: 177
# 1823
# length dictionary with all distancces: 176
# 1824
# length dictionary with all distancces: 175
# 1825
# length dictionary with all distancces: 174
# 1826
# length dictionary with all distancces: 173
# 1827
# length dictionary with all distancces: 172
# 1828
# length dictionary with all distancces: 171
# 1829
# length dictionary with all distancces: 170
# 1830
# length dictionary with all distancces: 169
# 1831
# length dictionary with all distancces: 168
# 1832
# length dictionary with all distancces: 167
# 1833
# length dictionary with all distancces: 166
# 1834
# length dictionary with all distancces: 165
# 1835
# length dictionary with all distancces: 164
# 1836
# length dictionary with all distancces: 163
# 1837
# length dictionary with all distancces: 162
# 1838
# length dictionary with all distancces: 161
# 1839
# length dictionary with all distancces: 160
# 1840
# length dictionary with all distancces: 159
# 1841
# length dictionary with all distancces: 158
# 1842
# length dictionary with all distancces: 157
# 1843
# length dictionary with all distancces: 156
# 1844
# length dictionary with all distancces: 155
# 1845
# length dictionary with all distancces: 154
# 1846
# length dictionary with all distancces: 153
# 1847
# length dictionary with all distancces: 152
# 1848
# length dictionary with all distancces: 151
# 1849
# length dictionary with all distancces: 150
# 1850
# length dictionary with all distancces: 149
# 1851
# length dictionary with all distancces: 148
# 1852
# length dictionary with all distancces: 147
# 1853
# length dictionary with all distancces: 146
# 1854
# length dictionary with all distancces: 145
# 1855
# length dictionary with all distancces: 144
# 1856
# length dictionary with all distancces: 143
# 1857
# length dictionary with all distancces: 142
# 1858
# length dictionary with all distancces: 141
# 1859
# length dictionary with all distancces: 140
# 1860
# length dictionary with all distancces: 139
# 1861
# length dictionary with all distancces: 138
# 1862
# length dictionary with all distancces: 137
# 1863
# length dictionary with all distancces: 136
# 1864
# length dictionary with all distancces: 135
# 1865
# length dictionary with all distancces: 134
# 1866
# length dictionary with all distancces: 133
# 1867
# length dictionary with all distancces: 132
# 1868
# length dictionary with all distancces: 131
# 1869
# length dictionary with all distancces: 130
# 1870
# length dictionary with all distancces: 129
# 1871
# length dictionary with all distancces: 128
# 1872
# length dictionary with all distancces: 127
# 1873
# length dictionary with all distancces: 126
# 1874
# length dictionary with all distancces: 125
# 1875
# length dictionary with all distancces: 124
# 1876
# length dictionary with all distancces: 123
# 1877
# length dictionary with all distancces: 122
# 1878
# length dictionary with all distancces: 121
# 1879
# length dictionary with all distancces: 120
# 1880
# length dictionary with all distancces: 119
# 1881
# length dictionary with all distancces: 118
# 1882
# length dictionary with all distancces: 117
# 1883
# length dictionary with all distancces: 116
# 1884
# length dictionary with all distancces: 115
# 1885
# length dictionary with all distancces: 114
# 1886
# length dictionary with all distancces: 113
# 1887
# length dictionary with all distancces: 112
# 1888
# length dictionary with all distancces: 111
# 1889
# length dictionary with all distancces: 110
# 1890
# length dictionary with all distancces: 109
# 1891
# length dictionary with all distancces: 108
# 1892
# length dictionary with all distancces: 107
# 1893
# length dictionary with all distancces: 106
# 1894
# length dictionary with all distancces: 105
# 1895
# length dictionary with all distancces: 104
# 1896
# length dictionary with all distancces: 103
# 1897
# length dictionary with all distancces: 102
# 1898
# length dictionary with all distancces: 101
# 1899
# length dictionary with all distancces: 100
# 1900
# length dictionary with all distancces: 99
# 1901
# length dictionary with all distancces: 98
# 1902
# length dictionary with all distancces: 97
# 1903
# length dictionary with all distancces: 96
# 1904
# length dictionary with all distancces: 95
# 1905
# length dictionary with all distancces: 94
# 1906
# length dictionary with all distancces: 93
# 1907
# length dictionary with all distancces: 92
# 1908
# length dictionary with all distancces: 91
# 1909
# length dictionary with all distancces: 90
# 1910
# length dictionary with all distancces: 89
# 1911
# length dictionary with all distancces: 88
# 1912
# length dictionary with all distancces: 87
# 1913
# length dictionary with all distancces: 86
# 1914
# length dictionary with all distancces: 85
# 1915
# length dictionary with all distancces: 84
# 1916
# length dictionary with all distancces: 83
# 1917
# length dictionary with all distancces: 82
# 1918
# length dictionary with all distancces: 81
# 1919
# length dictionary with all distancces: 80
# 1920
# length dictionary with all distancces: 79
# 1921
# length dictionary with all distancces: 78
# 1922
# length dictionary with all distancces: 77
# 1923
# length dictionary with all distancces: 76
# 1924
# length dictionary with all distancces: 75
# 1925
# length dictionary with all distancces: 74
# 1926
# length dictionary with all distancces: 73
# 1927
# length dictionary with all distancces: 72
# 1928
# length dictionary with all distancces: 71
# 1929
# length dictionary with all distancces: 70
# 1930
# length dictionary with all distancces: 69
# 1931
# length dictionary with all distancces: 68
# 1932
# length dictionary with all distancces: 67
# 1933
# length dictionary with all distancces: 66
# 1934
# length dictionary with all distancces: 65
# 1935
# length dictionary with all distancces: 64
# 1936
# length dictionary with all distancces: 63
# 1937
# length dictionary with all distancces: 62
# 1938
# length dictionary with all distancces: 61
# 1939
# length dictionary with all distancces: 60
# 1940
# length dictionary with all distancces: 59
# 1941
# length dictionary with all distancces: 58
# 1942
# length dictionary with all distancces: 57
# 1943
# length dictionary with all distancces: 56
# 1944
# length dictionary with all distancces: 55
# 1945
# length dictionary with all distancces: 54
# 1946
# length dictionary with all distancces: 53
# 1947
# length dictionary with all distancces: 52
# 1948
# length dictionary with all distancces: 51
# 1949
# length dictionary with all distancces: 50
# 1950
# length dictionary with all distancces: 49
# 1951
# length dictionary with all distancces: 48
# 1952
# length dictionary with all distancces: 47
# 1953
# length dictionary with all distancces: 46
# 1954
# length dictionary with all distancces: 45
# 1955
# length dictionary with all distancces: 44
# 1956
# length dictionary with all distancces: 43
# 1957
# length dictionary with all distancces: 42
# 1958
# length dictionary with all distancces: 41
# 1959
# length dictionary with all distancces: 40
# 1960
# length dictionary with all distancces: 39
# 1961
# length dictionary with all distancces: 38
# 1962
# length dictionary with all distancces: 37
# 1963
# length dictionary with all distancces: 36
# 1964
# length dictionary with all distancces: 35
# 1965
# length dictionary with all distancces: 34
# 1966
# length dictionary with all distancces: 33
# 1967
# length dictionary with all distancces: 32
# 1968
# length dictionary with all distancces: 31
# 1969
# length dictionary with all distancces: 30
# 1970
# length dictionary with all distancces: 29
# 1971
# length dictionary with all distancces: 28
# 1972
# length dictionary with all distancces: 27
# 1973
# length dictionary with all distancces: 26
# 1974
# length dictionary with all distancces: 25
# 1975
# length dictionary with all distancces: 24
# 1976
# length dictionary with all distancces: 23
# 1977
# length dictionary with all distancces: 22
# 1978
# length dictionary with all distancces: 21
# 1979
# length dictionary with all distancces: 20
# 1980
# length dictionary with all distancces: 19
# 1981
# length dictionary with all distancces: 18
# 1982
# length dictionary with all distancces: 17
# 1983
# length dictionary with all distancces: 16
# 1984
# length dictionary with all distancces: 15
# 1985
# length dictionary with all distancces: 14
# 1986
# length dictionary with all distancces: 13
# 1987
# length dictionary with all distancces: 12
# 1988
# length dictionary with all distancces: 11
# 1989
# length dictionary with all distancces: 10
# 1990
# length dictionary with all distancces: 9
# 1991
# length dictionary with all distancces: 8
# 1992
# length dictionary with all distancces: 7
# 1993
# length dictionary with all distancces: 6
# 1994
# length dictionary with all distancces: 5
# 1995
# length dictionary with all distancces: 4
# 1996
# length dictionary with all distancces: 3
# 1997
# length dictionary with all distancces: 2
# {'1994': array([4.58832773, 3.22338812, 1.        ]), '1997': array([-2.68932235, -1.79241047,  1.99414062])}

# %% [markdown]
# # Test the algorithm
# - loop does not make sense, or changing parameters, there are none to change and each round will be identical
# - implement some visualisation!
# - visualize dendogram somehow?

# %%
x = data[0] 
y=data[1]

xClusterMidPoints = []
yClusterMidPoints = []

for key, value in mapHashToPoint.items():
    xClusterMidPoints.append(value[0])
    yClusterMidPoints.append(value[1])


plt.plot(x, y, "x", color = "yellow") 
plt.plot(xClusterMidPoints, yClusterMidPoints, "x", color = "green") 

plt.axis("equal") 
plt.show()

# %%
# assign each point to closer mid point to have two clusters

firstMidPoint = [xClusterMidPoints[0], yClusterMidPoints[0]]
secondMidPoint = [xClusterMidPoints[1], yClusterMidPoints[1]]

cluster1 = []
cluster2 = []

dataCopy = data.copy().T

for i in range(len(dataCopy)):
        # divide every point in coordinates and label
        coordinate = dataCopy[i]

        # get distance to both k
        distanceToR1 = getEuclideanDistance(firstMidPoint[0],firstMidPoint[1], coordinate[0], coordinate[1])
        distanceToR2 = getEuclideanDistance(secondMidPoint[0],secondMidPoint[1], coordinate[0], coordinate[1])

        # append to cluster of k to which point is closer
        if distanceToR1 < distanceToR2:
            cluster1.append(coordinate)
        else:
            cluster2.append(coordinate)


cluster1 = np.array(cluster1)
cluster2 = np.array(cluster2)


xCluster1 = cluster1[:, 0] 
yCluster1 = cluster1[:, 1] 

xCluster2 = cluster2[:, 0] 
yCluster2 = cluster2[:, 1] 

print(xClusterMidPoints)
print(yClusterMidPoints)

plt.plot(xCluster1, yCluster1, "x", color = "yellow") 
plt.plot(xCluster2, yCluster2, "x", color = "orange") 

plt.plot(xClusterMidPoints, yClusterMidPoints, "x", color = "green") 

plt.axis("equal") 
plt.show()
# Out:
# [4.588327734372445, -2.689322352947907]
# [3.2233881235246424, -1.7924104718314693]

# %%
# add different colours for true labels

mask = np.isin(element = cluster1[:, 2],test_elements = 1)
TrueCluster1 = cluster1[mask]

mask = np.isin(element = cluster1[:, 2],test_elements = 1)
FalseCluster1 = cluster1[~mask]

mask = np.isin(element = cluster2[:, 2],test_elements = 2)
TrueCluster2 = cluster2[mask]


mask = np.isin(element = cluster2[:, 2],test_elements = 2)
FalseCluster2 = cluster2[~mask]

print(f"total: {len(TrueCluster1) +len(FalseCluster1) + len(TrueCluster2) + len(FalseCluster2)}")


xCluster1True = TrueCluster1[:, 0] 
yCluster1True = TrueCluster1[:, 1] 

xCluster1False = FalseCluster1[:, 0] 
yCluster1False = FalseCluster1[:, 1] 

xCluster2True = TrueCluster2[:, 0] 
yCluster2True = TrueCluster2[:, 1] 

xCluster2False = FalseCluster2[:, 0] 
yCluster2False = FalseCluster2[:, 1] 

plt.plot(xCluster1True, yCluster1True, "x", color = "yellow") 
plt.plot(xCluster2True, yCluster2True, "x", color = "orange") 
plt.plot(xCluster1False, yCluster1False, "x", color = "blue") 
plt.plot(xCluster2False, yCluster2False, "x", color = "green") 


plt.plot(xClusterMidPoints, yClusterMidPoints, "x", color = "red") 

plt.axis("equal") 
plt.show()
# Out:
# total: 1000

# %%
from scipy.cluster import hierarchy
Z = hierarchy.linkage(data.T, 'single')
hierarchy.set_link_color_palette(['m', 'c', 'y', 'k'])
plt.figure()

dn = hierarchy.dendrogram(Z)

# %% [markdown]
# # Exercise 3
#
# Implement the DBScan algorithm as described in https://www.youtube.com/watch?v=_A9Tq6mGtLI
# and demonstrate graphically the process with a series of snapshots of the process at key points with adequate descriptions.

# %%
# save unprocessed data and add 4th coloumn with hash for each coloumn
unprocessedData = data.T
unprocessedData = unprocessedData

#unprocessedData = np.array([[1,2,1],[1,3,1], [2,3,1], [1,1,1], [3,2,1], [3,3,1], [8,8,2], [9,7,2], [9,9,2], [9,10,2], [8,10,2], [7, 8, 2], [9,8,2]])

identifiers = np.array([hash(str(row)) for row in unprocessedData])
identifiers = identifiers[:, np.newaxis]  
unprocessedData = np.concatenate((unprocessedData, identifiers), axis=1)

# dict with data and hash identifier
copyOriginalArray = unprocessedData.copy()
mapHashToDataPoints = {}
for row in copyOriginalArray:
    mapHashToDataPoints[row[3]] = row[:3]
noiseDataPoints = []

# initiate parameters
e = 0.6
MinPts = 10


# loop while dataPoints are still unprocessed:
allClusters = []
while unprocessedData.shape[0] != 0:
    # chose random starting point and delete from unprocessedData
    np.random.shuffle(unprocessedData)
    startingPoint = unprocessedData[0, :] 
    unprocessedData = np.delete(unprocessedData, 0, axis = 0)

    # calculate distance from startingPoint to all other points in unprocessedData
    distanceToStartingPointDict = {}
    for dataPoint in unprocessedData: 
        distanceToStartingPointDict[dataPoint[3]] = getEuclideanDistance(startingPoint[0], startingPoint[1], dataPoint[0], dataPoint[1])

    # all neighbours in a dict
    neighboursDict = { key: mapHashToDataPoints[key] for key, value in distanceToStartingPointDict.items() if value <= e }
    print(len(neighboursDict)+1)


    xNeighbour = []
    yNeighbour = []
    for key, value in neighboursDict.items():
        xNeighbour.append(value[0])
        yNeighbour.append(value[1])


    # plot 
    if unprocessedData.shape[0] != 0:
        print("Here we see all data points, that are still unprocessed. \n The red point is the random current starting point.\n In orange we can see the radius in which we are looking for neighbours and count their number. \n All purple points are withing the radius.")
        x = unprocessedData.T[0] 
        y = unprocessedData.T[1]
        plt.plot(x, y, "x", color = "blue") 
        plt.plot(xNeighbour, yNeighbour, "x", color = "purple") 
        plt.plot(startingPoint[0], startingPoint[1], "x", color = "red") 
        circle = Circle((startingPoint[0], startingPoint[1]), radius=e, color='orange', fill=False, linewidth=1)
        plt.gca().add_patch(circle)
        plt.xlim(-8, 8)
        plt.ylim(-8, 8)
        plt.axis("equal") 
        plt .show()



    if len(neighboursDict)+1 >= MinPts:

        currentCluster = []
        currentCluster.append(startingPoint[:3])
        counter = 0
        # while loop, to get all neighbours of neighbours until no neighbours any more
        while len(neighboursDict) > 0:
            firstKey = next(iter(neighboursDict)) # get first key of dictionary (is index of one of neighbouring points)
            currentPoint = neighboursDict[firstKey]


            # calc all distances to current neighbour = CurrentPoint
            distanceTocurrentPointDict = {}
            for dataPoint in unprocessedData: 
                if not ((currentPoint==dataPoint[:3]).all()):
                    distanceTocurrentPointDict[dataPoint[3]] = getEuclideanDistance(currentPoint[0], currentPoint[1], dataPoint[0], dataPoint[1])

            # add all neighbourNeighbours within reach to neighbour dictionary (if not already in there)
            neighboursNeighboursDict = {}      
            neighboursNeighboursDict = {key: mapHashToDataPoints[key] for key, value in distanceTocurrentPointDict.items() if value <= e }
            onlyNewPointsDict = {key: value for key, value in neighboursNeighboursDict.items() if key not in neighboursDict}
            neighboursDict.update(onlyNewPointsDict)

            if counter%100 == 0:
                print("The starting point had more than minPts neighbours. \n All yellow points are neighbours and are going to be clustered in one cluster. \n Furthermore for each yellow point all neighbours will also be added to the current cluster.")
                x = unprocessedData.T[0] 
                y = unprocessedData.T[1]

                xNeighbour = []
                yNeighbour = []
                for key, value in neighboursDict.items():
                    xNeighbour.append(value[0])
                    yNeighbour.append(value[1])


                plt.plot(x, y, "x", color = "darkgreen") 
                plt.plot(xNeighbour, yNeighbour, "x", color = "yellow") 
                plt.plot(currentPoint[0], currentPoint[1], "x", color = "red") 
                circle = Circle((currentPoint[0], currentPoint[1]), radius=e, color='orange', fill=False, linewidth=1)
                plt.gca().add_patch(circle)
                plt.xlim(-8, 8)
                plt.ylim(-8, 8)
                plt.axis("equal") 
                plt.show()            
            

            # delete all dataPoints from unprocessedData if already in neighboursDict:
            hashIdentifiers = unprocessedData[:, 3]
            doubleKeys = np.array(list(neighboursDict.keys()))
            mask = ~np.isin(hashIdentifiers, doubleKeys)
            unprocessedData = unprocessedData[mask]

            # add currentPoint to cluster
            currentCluster.append(currentPoint)

            # delete currentPoint from neighboursDict
            del neighboursDict[firstKey]
            counter+=1
            #print(len(neighboursDict))

        # append currentCluster to allClusters  
        allClusters.append(currentCluster)
        #print(f"cluster data: {currentCluster}")

    else: 
        noiseDataPoints.append(startingPoint) 
        #print(f"noise data: {noiseDataPoints}")

    #print(len(unprocessedData))

#allClusters = np.array(allClusters)
#noiseDataPoints = np.array(noiseDataPoints)
print(allClusters)
print(noiseDataPoints)
# Out:
# 34
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# The starting point had more than minPts neighbours.
#  All yellow points are neighbours and are going to be clustered in one cluster.
#  Furthermore for each yellow point all neighbours will also be added to the current cluster.
# The starting point had more than minPts neighbours.
#  All yellow points are neighbours and are going to be clustered in one cluster.
#  Furthermore for each yellow point all neighbours will also be added to the current cluster.
# The starting point had more than minPts neighbours.
#  All yellow points are neighbours and are going to be clustered in one cluster.
#  Furthermore for each yellow point all neighbours will also be added to the current cluster.
# The starting point had more than minPts neighbours.
#  All yellow points are neighbours and are going to be clustered in one cluster.
#  Furthermore for each yellow point all neighbours will also be added to the current cluster.
# The starting point had more than minPts neighbours.
#  All yellow points are neighbours and are going to be clustered in one cluster.
#  Furthermore for each yellow point all neighbours will also be added to the current cluster.
# 23
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# The starting point had more than minPts neighbours.
#  All yellow points are neighbours and are going to be clustered in one cluster.
#  Furthermore for each yellow point all neighbours will also be added to the current cluster.
# The starting point had more than minPts neighbours.
#  All yellow points are neighbours and are going to be clustered in one cluster.
#  Furthermore for each yellow point all neighbours will also be added to the current cluster.
# The starting point had more than minPts neighbours.
#  All yellow points are neighbours and are going to be clustered in one cluster.
#  Furthermore for each yellow point all neighbours will also be added to the current cluster.
# The starting point had more than minPts neighbours.
#  All yellow points are neighbours and are going to be clustered in one cluster.
#  Furthermore for each yellow point all neighbours will also be added to the current cluster.
# The starting point had more than minPts neighbours.
#  All yellow points are neighbours and are going to be clustered in one cluster.
#  Furthermore for each yellow point all neighbours will also be added to the current cluster.
# 2
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 3
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 6
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 3
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 2
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 2
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 5
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 2
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 2
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 2
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 2
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 2
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 2
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 2
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 2
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 2
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 2
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 4
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 2
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 3
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# Here we see all data points, that are still unprocessed.
#  The red point is the random current starting point.
#  In orange we can see the radius in which we are looking for neighbours and count their number.
#  All purple points are withing the radius.
# 1
# [[array([1.64606449, 2.30350752, 1.        ]), array([1.92665849, 2.47603803, 1.        ]), array([1.94735726, 2.7975356 , 1.        ]), array([1.20354709, 2.13792761, 1.        ]), array([2.03596558, 1.94304521, 1.        ]), array([1.55103762, 2.29273182, 1.        ]), array([1.18870219, 2.02992213, 1.        ]), array([1.6828704, 1.9048676, 1.       ]), array([1.95453666, 2.75030267, 1.        ]), array([1.99358539, 2.67624121, 1.        ]), array([1.96214699, 1.79686704, 1.        ]), array([1.48217883, 2.85773842, 1.        ]), array([1.89274491, 2.65331599, 1.        ]), array([2.22297869, 2.38829793, 1.        ]), array([1.52584379, 2.60278284, 1.        ]), array([2.06939081, 1.91565035, 1.        ]), array([1.81536047, 1.88717221, 1.        ]), array([1.90327315, 1.95214539, 1.        ]), array([1.51907747, 2.50391093, 1.        ]), array([2.05949968, 2.71852955, 1.        ]), array([1.86114623, 2.41076512, 1.        ]), array([2.14398355, 2.03148889, 1.        ]), array([1.31740546, 2.73598888, 1.        ]), array([2.22465314, 2.25902987, 1.        ]), array([1.85090789, 2.09629831, 1.        ]), array([1.57688497, 1.7896928 , 1.        ]), array([1.50812988, 1.78311018, 1.        ]), array([1.81904327, 2.85900919, 1.        ]), array([1.94761788, 2.63505221, 1.        ]), array([2.1702625 , 2.44616191, 1.        ]), array([1.69124692, 2.73549756, 1.        ]), array([1.35331813, 2.69356089, 1.        ]), array([1.65565077, 1.84544036, 1.        ]), array([1.64699439, 2.59638821, 1.        ]), array([2.10133626, 2.96020434, 1.        ]), array([1.72828662, 2.9197638 , 1.        ]), array([2.42823647, 2.23506127, 1.        ]), array([2.36860087, 2.31276978, 1.        ]), array([2.27272251, 2.3564743 , 1.        ]), array([2.27616041, 2.86283378, 1.        ]), array([2.02842863, 3.04141453, 1.        ]), array([2.31242459, 2.63397659, 1.        ]), array([2.44051093, 2.39606028, 1.        ]), array([2.08890919, 2.93987745, 1.        ]), array([2.12388489, 2.71754652, 1.        ]), array([2.2481581 , 2.44241892, 1.        ]), array([1.93539077, 2.97198588, 1.        ]), array([1.73565342, 2.98392807, 1.        ]), array([2.36893002, 2.39317104, 1.        ]), array([1.81297639, 2.98769488, 1.        ]), array([1.5239882 , 2.89830484, 1.        ]), array([2.32847215, 2.47118374, 1.        ]), array([2.24766613, 3.21719358, 1.        ]), array([1.78910689, 3.1746956 , 1.        ]), array([2.46934833, 2.83316133, 1.        ]), array([2.49644113, 2.73364235, 1.        ]), array([2.32468328, 2.94381376, 1.        ]), array([1.91062939, 3.17715647, 1.        ]), array([2.50076212, 2.85688224, 1.        ]), array([1.6773311 , 3.28597547, 1.        ]), array([1.6110685 , 3.06307359, 1.        ]), array([2.12784413, 3.13896796, 1.        ]), array([2.11725581, 3.10860091, 1.        ]), array([2.51245099, 2.82240466, 1.        ]), array([1.97837368, 3.30699766, 1.        ]), array([1.84620642, 3.11218581, 1.        ]), array([2.47076243, 3.05844213, 1.        ]), array([1.59621063, 3.04610446, 1.        ]), array([2.41544468, 2.95445185, 1.        ]), array([1.99661022, 3.1385593 , 1.        ]), array([2.39178106, 3.018246  , 1.        ]), array([2.24242739, 3.27012226, 1.        ]), array([2.0109237 , 3.16564494, 1.        ]), array([2.00059332, 3.30652879, 1.        ]), array([2.27683038, 3.0618067 , 1.        ]), array([2.21488045, 3.20502277, 1.        ]), array([2.50861101, 1.89086354, 1.        ]), array([1.87008286, 1.57750318, 1.        ]), array([2.44128037, 2.14635125, 1.        ]), array([2.08190047, 1.72214625, 1.        ]), array([2.39975905, 2.03711176, 1.        ]), array([2.33929493, 1.89447234, 1.        ]), array([2.51552287, 1.87073649, 1.        ]), array([2.29518833, 1.73054732, 1.        ]), array([2.41698931, 1.87393725, 1.        ]), array([2.55790537, 1.87077596, 1.        ]), array([1.75480789, 1.32920222, 1.        ]), array([2.55830069, 2.61238903, 1.        ]), array([1.50577294, 3.25756845, 1.         ...
# [array([-2.32042497e-01,  1.27754246e+00,  2.00000000e+00,  4.82446832e+18]), array([-1.71110393e+00,  1.28227072e+00,  2.00000000e+00, -7.73521190e+18]), array([ 4.89406617e+00,  4.76227312e+00,  1.00000000e+00, -2.95086178e+18]), array([-8.07567181e-01, -7.58568924e+00,  2.00000000e+00,  6.16465866e+18]), array([ 6.96230572e+00,  4.06468435e+00,  1.00000000e+00, -6.05595523e+18]), array([ 3.04431919e+00,  3.41389673e-01,  1.00000000e+00, -3.98288474e+18]), array([-4.84033905e-01, -7.38953455e+00,  2.00000000e+00,  1.64577016e+18]), array([ 5.34159822e+00,  4.01358096e+00,  1.00000000e+00, -9.92027865e+17]), array([-2.83070422e+00, -8.30388446e+00,  2.00000000e+00,  8.76763869e+18]), array([-6.06083957e+00, -5.43545749e+00,  2.00000000e+00, -1.70534315e+18]), array([ 6.27608885e-01, -6.50039325e-01,  2.00000000e+00, -1.24288475e+18]), array([-7.84487101e-02, -6.40195616e+00,  2.00000000e+00,  6.55950906e+18]), array([-5.55241289e+00, -7.01748337e+00,  2.00000000e+00,  6.46349112e+17]), array([-2.00174197e+00, -9.15030580e+00,  2.00000000e+00,  6.52344444e+18]), array([ 7.05427489e-01,  2.23412176e-01,  2.00000000e+00, -4.09548443e+18]), array([-3.31900373e+00, -8.95117303e+00,  2.00000000e+00, -6.77445693e+18]), array([-5.81353746e+00, -5.43685019e+00,  2.00000000e+00, -6.76708645e+18]), array([ 2.08764671e+00, -1.27525018e+00,  2.00000000e+00, -3.70122417e+18]), array([-2.79306123e+00, -8.02684727e+00,  2.00000000e+00, -9.31842040e+17]), array([-1.76045718e+00,  2.99596011e+00,  2.00000000e+00,  3.46306700e+17]), array([-6.14445288e+00, -5.37058736e+00,  2.00000000e+00, -2.99632075e+18]), array([-3.01160008e+00, -8.42390253e+00,  2.00000000e+00,  6.48285983e+18]), array([ 6.11497552e+00,  2.47435317e+00,  1.00000000e+00, -6.03038231e+17]), array([-4.94104906e+00, -7.99330640e+00,  2.00000000e+00, -1.38898423e+18]), array([-1.63696603e-01,  2.20093075e+00,  1.00000000e+00, -4.62375893e+18]), array([-1.35317153e+00,  1.85803605e+00,  2.00000000e+00, -5.22170754e+18]), array([-4.13812939e+00, -8.02329878e+00,  2.00000000e+00,  8.17730630e+17]), array([-4.79797528e-01,  9.64357440e-01,  2.00000000e+00, -7.26447568e+18]), array([-6.33208879e+00, -6.53627731e-01,  2.00000000e+00, -6.49624556e+18]), array([-1.06036598e+00, -7.56194239e+00,  2.00000000e+00, -2.01773595e+18]), array([-9.89371431e-01,  9.66485003e-01,  2.00000000e+00, -6.79777606e+18]), array([6.06835041e+00, 2.75820853e+00, 1.00000000e+00, 9.09776218e+18]), array([5.57133851e+00, 4.86367951e+00, 1.00000000e+00, 2.56945327e+18]), array([1.80079467e-01, 8.27667521e-01, 1.00000000e+00, 2.64337911e+18]), array([-3.76176792e+00,  3.03876770e+00,  2.00000000e+00,  6.86693359e+18]), array([-3.43306205e+00,  2.85165457e+00,  2.00000000e+00,  8.49656130e+18]), array([-6.07720606e+00, -1.97478174e+00,  2.00000000e+00, -5.77255794e+18]), array([5.78407307e-01, 9.14634406e-01, 2.00000000e+00, 3.37743973e+18]), array([1.10341682e+00, 8.71914687e-01, 1.00000000e+00, 1.54118051e+18]), array([-1.83442115e+00, -8.22673014e+00,  2.00000000e+00, -2.14014998e+18]), array([-3.25637631e+00, -8.55610346e+00,  2.00000000e+00, -9.09133255e+18]), array([ 1.03652595e-01,  2.80561261e+00,  1.00000000e+00, -6.23179271e+16]), array([-2.59904858e+00, -7.84119690e+00,  2.00000000e+00, -1.85632881e+18]), array([-3.31559813e+00, -7.43891889e+00,  2.00000000e+00, -8.41560537e+18]), array([-4.03357075e+00, -8.09103900e+00,  2.00000000e+00, -2.38102257e+18]), array([-2.54535829e+00, -7.49672069e+00,  2.00000000e+00,  3.35810664e+18]), array([2.23297299e-02, 2.13549332e+00, 1.00000000e+00, 1.31829658e+18]), array([-4.95500269e-01,  2.74539720e-01,  2.00000000e+00, -4.68633324e+18]), array([-1.58415463e+00,  2.96262924e+00,  2.00000000e+00, -6.99733270e+18]), array([-1.82945273e+00, -7.71100340e+00,  2.00000000e+00, -8.54321169e+18]), array([-6.60083630e+00, -2.46324906e+00,  2.00000000e+00,  7.94069309e+18]), array([-5.46089285e+00,  9.96280415e-01,  2.00000000e+00,  2.17555275e+18]), array([-2.43849252e ...

# %%
len(allClusters)
# Out:
# 2

# %%
len(noiseDataPoints)
# Out:
# 56

# %%
# visualize final outcome:

xCluster1 = []
for dataPoint in allClusters[0]:
    xCluster1.append(dataPoint[0])

print(xCluster1)

yCluster1 = []
for dataPoint in allClusters[0]:
    yCluster1.append(dataPoint[1])

print(len(yCluster1))


xCluster2 = []
for dataPoint in allClusters[1]:
    xCluster2.append(dataPoint[0])


yCluster2 = []
for dataPoint in allClusters[1]:
    yCluster2.append(dataPoint[1])


# xCluster3 = []
# for dataPoint in allClusters[2]:
#     xCluster3.append(dataPoint[0])


# yCluster3 = []
# for dataPoint in allClusters[2]:
#     yCluster3.append(dataPoint[1])

xNoise = []
for dataPoint in noiseDataPoints:
    xNoise.append(dataPoint[0])

print(len(xNoise))

yNoise = []
for dataPoint in noiseDataPoints:
    yNoise.append(dataPoint[1])

plt.plot(xCluster1, yCluster1, "x", color = "purple") 
plt.plot(xCluster2, yCluster2, "x", color = "blue") 
#plt.plot(xCluster3, yCluster3, "x", color = "darkred") 


plt.plot(xNoise, yNoise, "x", color = "grey") 



plt.axis("equal") 
plt .show()
# Out:
# [1.6460644907766806, 1.926658485676213, 1.947357262890454, 1.203547094070056, 2.0359655757847026, 1.5510376186653985, 1.1887021935029118, 1.682870399634281, 1.954536658473904, 1.9935853870268134, 1.962146985742854, 1.4821788272018284, 1.892744913029948, 2.22297869491687, 1.525843791688298, 2.0693908127845324, 1.8153604697444365, 1.9032731492648405, 1.5190774690238735, 2.0594996806938317, 1.8611462251918263, 2.143983554479581, 1.3174054556819228, 2.2246531434722483, 1.850907891640888, 1.576884969986768, 1.5081298824790437, 1.819043270998444, 1.9476178838593379, 2.1702624951650398, 1.6912469155289427, 1.3533181332535287, 1.6556507688492277, 1.6469943934557632, 2.10133625887454, 1.7282866198239069, 2.4282364655675406, 2.3686008671524728, 2.2727225146084717, 2.276160408401492, 2.0284286251531007, 2.3124245863234987, 2.4405109324179106, 2.088909189081259, 2.12388489011817, 2.248158102124121, 1.9353907748470809, 1.7356534182565981, 2.3689300192780265, 1.812976385125442, 1.5239882048881797, 2.3284721539315685, 2.247666127587358, 1.7891068947838196, 2.469348333112312, 2.496441127687925, 2.3246832756690043, 1.9106293940223955, 2.500762117118583, 1.6773310975431783, 1.611068500277878, 2.127844125000752, 2.1172558100919483, 2.512450991333986, 1.9783736762712447, 1.8462064243243763, 2.4707624317028407, 1.5962106274168726, 2.4154446819732582, 1.996610219732508, 2.3917810648848237, 2.2424273887241504, 2.010923704945059, 2.0005933174135797, 2.2768303805461434, 2.214880448251325, 2.5086110145689497, 1.870082861112102, 2.441280372481505, 2.081900466949609, 2.3997590537856084, 2.339294927113834, 2.5155228669458234, 2.2951883250642147, 2.4169893135310248, 2.557905374446138, 1.7548078857783802, 2.5583006856568002, 1.505772943406396, 1.0285406762097116, 2.6364056796229964, 2.7698326176504304, 2.7168080491716866, 2.6147213293689364, 2.6678318708132083, 2.6293603034483883, 2.624857500410932, 2.745243334015542, 2.5219533600665613, 0.7679162269480111, 0.8223332038762288, 2.666941735622466, 2.4021089670907108, 2.562388573228313, 2.561592859010823, 2.289206461047221, 2.4505295836429344, 2.382577478970518, 2.3638487912878676, 2.0152707120077373, 2.5403428578737146, 2.536276574593771, 2.5791211624088923, 2.861260425031123, 2.8389262307090286, 2.8421001491870928, 2.849830336853198, 2.9845593135912765, 3.0010277824245115, 2.7270000686938247, 3.009346251684293, 2.882356803865328, 2.9458504809803405, 2.9041173439999666, 2.741948727965818, 2.910654461961266, 2.735944066057771, 2.667888319578219, 2.722622541066475, 2.799742686478083, 2.5618423366493626, 2.8404805374209423, 2.8110210210909585, 2.7237637989059396, 2.821935788518032, 1.722027683994071, 2.3697127353047565, 1.9091828417494192, 2.1198558036210127, 2.0162077490809027, 2.3247602341038274, 2.9122957743453153, 2.0690437167278946, 2.616446682226929, 2.5578522548724756, 2.6970883679121047, 2.400972073650339, 2.0046386036664874, 1.871460082191495, 3.0427895034204937, 2.8792045806261988, 2.971367632212287, 2.9495093422880188, 3.005977147416377, 2.9178498297543016, 2.938221588300264, 3.0591634511214965, 2.858678451423153, 3.000724723402529, 1.8127786379393986, 1.399864731620512, 3.10326425123098, 2.0271168557944717, 2.8686524882075295, 2.726876343482196, 2.781852401588217, 2.823826642775729, 2.3943993449675958, 2.3152991202297155, 3.0250296691622056, 2.9010835980463687, 2.9269315222147303, 2.917350466458382, 3.0215395910255287, 3.0774868705166667, 3.046954690026647, 3.0309547687143334, 2.407712025868781, 3.0230600184483807, 2.921271607797272, 2.570917292386018, 2.6856543344214403, 2.22369156239278, 1.7505183704169827, 2.253516105944224, 3.082157751250048, 3.0853711649760407, 3.1211380641816273, 3.046171913384304, 3.0861799060082724, 0.8526179729284169, 0.5927944962937919, 3.1696442906923448, 3.1346237890105724, 3.2622853530697933, 3.1802336254939276, 3.330208992268594, 3.239188786720226, 3.27063978190227, 3.1967756986440543, 3.2116648044471297, 3.2234636010003404, 3.2736171506141707, 3.3203420156498846, 3.162 ...
# 488
# 56

# %% [markdown]
# ### What we observed
#
# Since DBSCAN is a density based clustering method, cluster need to be similar in density and not to close together to be classified correctly. Also, e and minPts need to be well aligned with the data in order for the algorithm to work well.
#
# Also, "outliers" (i.e. points that are further away from the mean of their distributions than all the others) will likely be classified as noise.
#
# Since we did not implement the original DBSCAN (with core and border points being treated differently) the clustering is highly dependendon ehich random starting point are chosen by chance. This can decide for some pointswhether they will be classified as part of a cluster or noise!
#
#
# ### Here is an example with three clusters:

# %%
# test with having added more distributions (clusters)

# generate data

mean= [3, 5]
cov = [[1, 0], [0, 1]]
a = np.random.multivariate_normal(mean, cov, 500).T

new_col_a = np.ones((1, a.shape[1]))
a = np.append(a, new_col_a, axis = 0)

mean= [-3, -3]
cov = [[1, 0], [0, 1]]
b = np.random.multivariate_normal(mean, cov, 500).T

new_col_b = np.full((1, b.shape[1]), 2)
b = np.append(b, new_col_b, axis = 0)

mean= [7, -2]
cov = [[1, 0], [0, 1]]
d = np.random.multivariate_normal(mean, cov, 500).T

new_col_d = np.full((1, d.shape[1]), 3)
d = np.append(d, new_col_d, axis = 0)



c = np.concatenate((a, b, d) , axis = 1) 
c=c.T
np.random.shuffle(c)
data=c.T


# save unprocessed data and add 4th coloumn with hash for each coloumn
unprocessedData = data.T
unprocessedData = unprocessedData

#unprocessedData = np.array([[1,2,1],[1,3,1], [2,3,1], [1,1,1], [3,2,1], [3,3,1], [8,8,2], [9,7,2], [9,9,2], [9,10,2], [8,10,2], [7, 8, 2], [9,8,2]])

identifiers = np.array([hash(str(row)) for row in unprocessedData])
identifiers = identifiers[:, np.newaxis]  
unprocessedData = np.concatenate((unprocessedData, identifiers), axis=1)

# dict with data and hash identifier
copyOriginalArray = unprocessedData.copy()
mapHashToDataPoints = {}
for row in copyOriginalArray:
    mapHashToDataPoints[row[3]] = row[:3]
noiseDataPoints = []

# initiate parameters
e = 1
MinPts = 10


# loop while dataPoints are still unprocessed:
allClusters = []
while unprocessedData.shape[0] != 0:
    # chose random starting point and delete from unprocessedData
    np.random.shuffle(unprocessedData)
    startingPoint = unprocessedData[0, :] 
    unprocessedData = np.delete(unprocessedData, 0, axis = 0)

    # calculate distance from startingPoint to all other points in unprocessedData
    distanceToStartingPointDict = {}
    for dataPoint in unprocessedData: 
        distanceToStartingPointDict[dataPoint[3]] = getEuclideanDistance(startingPoint[0], startingPoint[1], dataPoint[0], dataPoint[1])

    # all neighbours in a dict
    neighboursDict = { key: mapHashToDataPoints[key] for key, value in distanceToStartingPointDict.items() if value <= e }
    print(len(neighboursDict)+1)


    xNeighbour = []
    yNeighbour = []
    for key, value in neighboursDict.items():
        xNeighbour.append(value[0])
        yNeighbour.append(value[1])


    # plot 
    if unprocessedData.shape[0] != 0:
        x = unprocessedData.T[0] 
        y = unprocessedData.T[1]
        plt.plot(x, y, "x", color = "blue") 
        plt.plot(xNeighbour, yNeighbour, "x", color = "purple") 
        plt.plot(startingPoint[0], startingPoint[1], "x", color = "red") 
        circle = Circle((startingPoint[0], startingPoint[1]), radius=e, color='orange', fill=False, linewidth=1)
        plt.gca().add_patch(circle)
        plt.xlim(-8, 12)
        plt.ylim(-8, 12)
        plt.axis("equal") 
        plt .show()



    if len(neighboursDict)+1 >= MinPts:

        currentCluster = []
        currentCluster.append(startingPoint[:3])
        counter = 0
        # while loop, to get all neighbours of neighbours until no neighbours any more
        while len(neighboursDict) > 0:
            firstKey = next(iter(neighboursDict)) # get first key of dictionary (is index of one of neighbouring points)
            currentPoint = neighboursDict[firstKey]


            # calc all distances to current neighbour = CurrentPoint
            distanceTocurrentPointDict = {}
            for dataPoint in unprocessedData: 
                if not ((currentPoint==dataPoint[:3]).all()):
                    distanceTocurrentPointDict[dataPoint[3]] = getEuclideanDistance(currentPoint[0], currentPoint[1], dataPoint[0], dataPoint[1])

            # add all neighbourNeighbours within reach to neighbour dictionary (if not already in there)
            neighboursNeighboursDict = {}      
            neighboursNeighboursDict = {key: mapHashToDataPoints[key] for key, value in distanceTocurrentPointDict.items() if value <= e }
            onlyNewPointsDict = {key: value for key, value in neighboursNeighboursDict.items() if key not in neighboursDict}
            neighboursDict.update(onlyNewPointsDict)

            if counter%100 == 0:
                x = unprocessedData.T[0] 
                y = unprocessedData.T[1]

                xNeighbour = []
                yNeighbour = []
                for key, value in neighboursDict.items():
                    xNeighbour.append(value[0])
                    yNeighbour.append(value[1])


                plt.plot(x, y, "x", color = "darkgreen") 
                plt.plot(xNeighbour, yNeighbour, "x", color = "yellow") 
                plt.plot(currentPoint[0], currentPoint[1], "x", color = "red") 
                circle = Circle((currentPoint[0], currentPoint[1]), radius=e, color='orange', fill=False, linewidth=1)
                plt.gca().add_patch(circle)
                plt.xlim(-8, 12)
                plt.ylim(-8, 12)
                plt.axis("equal") 
                plt.show()            
            

            # delete all dataPoints from unprocessedData if already in neighboursDict:
            hashIdentifiers = unprocessedData[:, 3]
            doubleKeys = np.array(list(neighboursDict.keys()))
            mask = ~np.isin(hashIdentifiers, doubleKeys)
            unprocessedData = unprocessedData[mask]

            # add currentPoint to cluster
            currentCluster.append(currentPoint)

            # delete currentPoint from neighboursDict
            del neighboursDict[firstKey]
            counter+=1
            #print(len(neighboursDict))

        # append currentCluster to allClusters  
        allClusters.append(currentCluster)
        #print(f"cluster data: {currentCluster}")

    else: 
        noiseDataPoints.append(startingPoint) 
        #print(f"noise data: {noiseDataPoints}")

    #print(len(unprocessedData))

#allClusters = np.array(allClusters)
#noiseDataPoints = np.array(noiseDataPoints)
print(allClusters)
print(noiseDataPoints)

# visualize final outcome:

xCluster1 = []
for dataPoint in allClusters[0]:
    xCluster1.append(dataPoint[0])

print(xCluster1)

yCluster1 = []
for dataPoint in allClusters[0]:
    yCluster1.append(dataPoint[1])

print(len(yCluster1))


xCluster2 = []
for dataPoint in allClusters[1]:
    xCluster2.append(dataPoint[0])


yCluster2 = []
for dataPoint in allClusters[1]:
    yCluster2.append(dataPoint[1])


xCluster3 = []
for dataPoint in allClusters[2]:
    xCluster3.append(dataPoint[0])


yCluster3 = []
for dataPoint in allClusters[2]:
    yCluster3.append(dataPoint[1])

xNoise = []
for dataPoint in noiseDataPoints:
    xNoise.append(dataPoint[0])

print(len(xNoise))

yNoise = []
for dataPoint in noiseDataPoints:
    yNoise.append(dataPoint[1])

plt.plot(xCluster1, yCluster1, "x", color = "purple") 
plt.plot(xCluster2, yCluster2, "x", color = "blue") 
plt.plot(xCluster3, yCluster3, "x", color = "darkred") 


plt.plot(xNoise, yNoise, "x", color = "grey") 



plt.axis("equal") 
plt .show()
# Out:
# 141
# 73
# 205
# 1
# 1
# [[array([3.84192503, 5.00523394, 1.        ]), array([3.3079296 , 4.99731267, 1.        ]), array([3.89013902, 5.41837243, 1.        ]), array([3.32754755, 5.74095167, 1.        ]), array([3.31623618, 5.30170479, 1.        ]), array([3.57060514, 4.41843538, 1.        ]), array([3.06418567, 4.40808879, 1.        ]), array([3.68312278, 4.77223241, 1.        ]), array([3.68663981, 4.58701069, 1.        ]), array([3.42822075, 5.37742354, 1.        ]), array([3.45293234, 5.22424999, 1.        ]), array([2.90706914, 5.00526648, 1.        ]), array([3.16348946, 4.39999526, 1.        ]), array([3.12555188, 5.40816083, 1.        ]), array([4.02940857, 5.52887675, 1.        ]), array([4.32530716, 4.72522658, 1.        ]), array([3.1632316, 5.009943 , 1.       ]), array([3.86531138, 4.68036218, 1.        ]), array([4.40087319, 5.23007145, 1.        ]), array([3.48678123, 5.65549354, 1.        ]), array([3.31019554, 5.25658923, 1.        ]), array([3.75532142, 4.70800077, 1.        ]), array([3.85796974, 5.05828616, 1.        ]), array([3.76775053, 4.77424473, 1.        ]), array([3.83204198, 4.12939771, 1.        ]), array([3.45847806, 4.94096086, 1.        ]), array([2.99112522, 5.35904436, 1.        ]), array([3.65704136, 4.17350692, 1.        ]), array([3.69099812, 4.56064922, 1.        ]), array([3.25805728, 4.23333202, 1.        ]), array([3.31082079, 5.69882553, 1.        ]), array([3.79348125, 4.52728009, 1.        ]), array([4.46744016, 5.07322564, 1.        ]), array([3.41533398, 4.6458575 , 1.        ]), array([3.67975971, 5.94251999, 1.        ]), array([4.26163965, 4.90505771, 1.        ]), array([4.32197872, 4.93622873, 1.        ]), array([4.24837547, 5.56691542, 1.        ]), array([3.48248386, 5.14904841, 1.        ]), array([3.66571343, 5.00110994, 1.        ]), array([4.49547258, 4.38928005, 1.        ]), array([3.77025373, 5.86353483, 1.        ]), array([3.73998423, 4.64161222, 1.        ]), array([4.22028919, 5.12451268, 1.        ]), array([3.47848522, 4.79515797, 1.        ]), array([3.43253451, 4.71891651, 1.        ]), array([3.94158009, 4.75665626, 1.        ]), array([3.56631065, 5.58256722, 1.        ]), array([4.57929178, 5.37189476, 1.        ]), array([3.47568221, 5.63638804, 1.        ]), array([3.11151039, 4.93855581, 1.        ]), array([3.79000207, 4.72624035, 1.        ]), array([3.17000012, 4.54940265, 1.        ]), array([3.22145494, 4.70759927, 1.        ]), array([4.09810142, 4.95398447, 1.        ]), array([3.35257949, 5.64058786, 1.        ]), array([3.79300222, 5.66111943, 1.        ]), array([4.31162511, 5.39741142, 1.        ]), array([4.06346622, 4.18970374, 1.        ]), array([3.09061576, 4.94707924, 1.        ]), array([3.70321423, 4.57107063, 1.        ]), array([3.79397709, 5.1010658 , 1.        ]), array([3.78398144, 4.23922325, 1.        ]), array([3.33005006, 4.77944533, 1.        ]), array([3.58355225, 5.36107178, 1.        ]), array([3.18629051, 5.31853148, 1.        ]), array([3.2500615 , 5.25553964, 1.        ]), array([4.60374801, 5.34223229, 1.        ]), array([3.5513796 , 5.83519754, 1.        ]), array([3.41661426, 4.48836026, 1.        ]), array([3.86566755, 4.94524017, 1.        ]), array([4.49552695, 5.5362537 , 1.        ]), array([4.21737683, 4.18148568, 1.        ]), array([3.25747374, 5.75588806, 1.        ]), array([3.66908041, 5.80096408, 1.        ]), array([3.95990195, 5.39135605, 1.        ]), array([3.85931769, 5.97939863, 1.        ]), array([3.72177617, 5.19200623, 1.        ]), array([3.57566357, 4.69308897, 1.        ]), array([3.69061701, 4.62730493, 1.        ]), array([4.06851975, 5.06870306, 1.        ]), array([3.19361631, 5.32369946, 1.        ]), array([4.32761603, 5.82011275, 1.        ]), array([4.00693979, 4.88972807, 1.        ]), array([3.57471683, 5.45293029, 1.        ]), array([4.08982277, 4.59038849, 1.        ]), array([3.03273229, 5.42712111, 1.        ]), array([4.25047998, 5.73993742, 1.        ]), array([2.93119931, 5.16755117, 1.         ...
# [array([ 6.42173214e+00,  4.43979094e+00,  1.00000000e+00, -3.62148508e+18]), array([-5.02937874e-01,  3.62716463e+00,  1.00000000e+00, -8.32713498e+18])]
# [3.8419250347368585, 3.3079296041658672, 3.8901390187593092, 3.327547554928379, 3.3162361802344122, 3.5706051403766668, 3.0641856721479805, 3.6831227790644627, 3.686639805267151, 3.428220749501573, 3.452932339488018, 2.9070691432356304, 3.1634894586615756, 3.1255518818479278, 4.029408574735172, 4.3253071556253335, 3.1632315978532684, 3.8653113810154998, 4.400873185634603, 3.486781227562605, 3.310195537909171, 3.7553214156419843, 3.8579697436271125, 3.767750533694683, 3.832041982136195, 3.4584780552764016, 2.99112522495107, 3.6570413567040903, 3.6909981204508315, 3.2580572826403436, 3.3108207867503876, 3.793481249229697, 4.467440162935522, 3.4153339796681546, 3.679759708271985, 4.261639651467525, 4.321978720981845, 4.248375465018476, 3.4824838638226345, 3.6657134320864144, 4.4954725756122516, 3.7702537262578684, 3.7399842347447034, 4.220289193542041, 3.478485223980815, 3.4325345138649097, 3.941580093030791, 3.566310645352936, 4.579291780497314, 3.475682209113579, 3.111510388334712, 3.790002071480473, 3.1700001162757365, 3.2214549444848957, 4.098101416751906, 3.352579493686027, 3.793002221187039, 4.311625110454229, 4.0634662198550755, 3.0906157587144336, 3.7032142324662862, 3.793977085164798, 3.783981444739443, 3.3300500559031194, 3.583552246401439, 3.1862905089758593, 3.2500615023326564, 4.603748009488097, 3.551379597162871, 3.416614256774203, 3.865667551023051, 4.495526946728518, 4.217376826968989, 3.2574737443939275, 3.669080409912332, 3.9599019465866414, 3.8593176876580464, 3.7217761711612756, 3.5756635684279354, 3.690617005421434, 4.068519746383414, 3.1936163149544416, 4.327616028481906, 4.006939788018965, 3.574716831794351, 4.089822771057426, 3.032732294771411, 4.250479984554784, 2.9311993096661477, 2.9313263256819866, 3.740425261200573, 3.5430832447894276, 3.4340603221400308, 3.0625505591425, 3.0289522020766912, 4.008207836400007, 3.805629403253016, 3.5108195108241307, 3.1130566516683507, 3.632027448814382, 3.2826971475506057, 3.366018679553023, 2.9560869868519406, 4.804226218109301, 3.924194082732947, 3.7153700374217395, 4.343766021380109, 3.0023837868581045, 4.009820445506424, 3.788220420657699, 3.609128103463064, 2.910673057806462, 3.439942601791107, 3.1807940602682483, 3.710726788323249, 3.1244778114887963, 4.056433323882157, 3.6629568535693884, 3.174885948142755, 3.136081559061834, 3.5830612014542815, 4.255956331776479, 4.31046471194685, 3.0256100278686637, 3.030934199369733, 4.191242040776195, 3.1356825080802744, 3.9211736709102043, 4.615108198013645, 4.391638789591851, 4.434172792219419, 3.3746039370841494, 4.199202067235958, 3.8470952341247946, 2.923435435090831, 4.174883847516012, 3.699677622795617, 4.134685945597443, 3.4165129940039156, 3.0594329798649067, 4.039577792258469, 2.857941588625752, 2.576946362831503, 2.3403348573344096, 2.739511145497179, 3.376729311409165, 2.832536648478493, 2.777147902391634, 3.092961584427814, 3.0398934077484365, 2.7115670239596565, 2.381394718068945, 2.3518558538073786, 2.8190573997573236, 2.525262463299233, 2.5432772571886213, 2.47921137647984, 2.706185405833496, 2.576260571931636, 2.9480289207084804, 2.8071607438649986, 3.231645930140107, 2.5948975025440095, 2.373308144437864, 2.631350048970893, 2.4086167016320177, 2.7023645901606663, 2.698039381500808, 2.616681035709635, 2.874402377629685, 2.801938145583546, 3.04401038335696, 2.5713856566628617, 2.5476330743333255, 3.490562444966786, 2.5215883456663235, 2.772889528460401, 2.553635536450894, 2.3710617467190147, 3.019653653628579, 3.2345514954621803, 2.6404588568289524, 2.5332705024719, 2.9634800987583834, 2.7132419497440416, 2.365807056010339, 3.070980226492809, 2.7499485906432883, 2.6718624820851136, 2.687841562156412, 2.990649414757601, 2.8803092915436665, 2.5662963874436793, 2.4657840562626396, 2.643821048803119, 2.687170656634437, 2.4641256246977874, 2.625284280458534, 2.8792922520344137, 2.9731070524950494, 2.595777468322179, 2.7448641627070436, 3.133722950589008, 2.573042873852162, 2.9449625865727462, 4.462979426221598, 3 ...
# 499
# 2

# %%
# generate data

mean= [3, 3]
cov = [[1, 0], [0, 1]]
a = np.random.multivariate_normal(mean, cov, 500).T

new_col_a = np.ones((1, a.shape[1]))
a = np.append(a, new_col_a, axis = 0)

mean= [-3, -3]
cov = [[2, 0], [0, 5]]
b = np.random.multivariate_normal(mean, cov, 500).T

new_col_b = np.full((1, b.shape[1]), 2)
b = np.append(b, new_col_b, axis = 0)

c = np.concatenate((a, b) , axis = 1) 
c=c.T
np.random.shuffle(c)
c=c.T

x = c[0] 
y=c[1]
labels=c[2]
plt.plot(x, y, "x") 
plt.axis("equal") 
plt .show()

# save and load data
np.savetxt("testData.csv", c, delimiter=",")
data = genfromtxt('testData.csv', delimiter=',')

# %%
# extra: full kMeans clustering
class KMeansClustering:

    # attributes
    k = None
    setWithDataTuples = None
    kDataPoinsInSet = None
    dictWithMappingAllPointsToK = None
    newKPointsinSet = None
    clusterCentroids = None
    clusterMemberships = None
    colourMap = None
    listOfColours = ["black", "green", "orange", "darkred", "darkblue", "lightblue", "purple", "pink", "cyan", "olive", "gray", "lightpink"]


    # constructor
    def __init__(self, setWithDataTuples, k):
        self.setWithDataTuples = setWithDataTuples
        self.k = k
        
    def __str__(self):
        return "K-Means Clustering Object" 
    


    # define all helper methods

    def __defineRandomKStart(self):
        # initiate list to store k random points
        kDataPointsInSet = set()
        # randomly draw k numbers in the rande of how long listWithDataTuples is
        rng = np.random.default_rng()
        randomPositionsOfKPoints = rng.integers(low=0, high=len(self.setWithDataTuples), size=self.k)
        # chose k points as random start points
        for i in randomPositionsOfKPoints:
            kDataPointsInSet.add(self.setWithDataTuples[i])
        
        # map colours to initial k points
        colourMap = {}
        number = 0
        for i in kDataPointsInSet:
            number += 1
            colourMap[i] = self.listOfColours[number]
        self.colourMap = colourMap
        
        return(kDataPointsInSet)
    


    def __mapAllPointsToNearestK(self, setOfKs):
        # calculate distance from each point to all k points
        dictWithMappingAllPointsToK = {}
        for k in setOfKs:
            dictWithMappingAllPointsToK[k] = []

        for i in self.setWithDataTuples:
            allDistancesFromOnePointToAllK = {}
            for l in setOfKs:
                allDistancesFromOnePointToAllK[l] = (self.__getEuclideanDistance(i[0], i[1], l[0], l[1]))
            # assign each point to the k-point which is closest
            # für minimales k:
            minK = min(allDistancesFromOnePointToAllK, key=allDistancesFromOnePointToAllK.get)
            dictWithMappingAllPointsToK[minK].append(i)

        return(dictWithMappingAllPointsToK)



    def __calcKNewMeans(self, dictWithMappingAllPointsToK):
        newKPointsinSet = set()
        for listWithPoints in dictWithMappingAllPointsToK.values():
            newMeanXCoordinate = []
            newMeanYCoordinate = []
            for i in range(len(listWithPoints)):
                newMeanXCoordinate.append(listWithPoints[i][0])
                newMeanX = round(sum(newMeanXCoordinate)/len(newMeanXCoordinate), 6)
                newMeanYCoordinate.append(listWithPoints[i][1])
                newMeanY = round(sum(newMeanYCoordinate)/len(newMeanYCoordinate), 6)
            newKPointsinSet.add((newMeanX, newMeanY,))

        # map colours to new centroids (that are closest to old ones)
        self.__reassignColorsToCentroids(newKPointsinSet)
            
        
        return(newKPointsinSet)
    

    def __reassignColorsToCentroids(self, newCentroids):
        # Dictionary to store the updated color mapping
        newColorMapping = {}
        
        # Find closest new centroid for each old centroid and assign the same color
        usedNewCentroids = set()
        for oldCentroid in self.colourMap:
            closestNewCentroid = min(newCentroids, key=lambda newCentroid: self.__getEuclideanDistance(oldCentroid[0], oldCentroid[1], newCentroid[0], newCentroid[1]))
            newColorMapping[closestNewCentroid] = self.colourMap[oldCentroid]
            usedNewCentroids.add(closestNewCentroid)
        
        # Find remaining colors from old centroids (i.e., those not reused)
        remainingColors = set(self.colourMap.values()) - set(newColorMapping.values())
        
        # Find new centroids that haven't been assigned a color yet
        unusedNewCentroids = set(newCentroids) - usedNewCentroids
        
        # Assign remaining colors from old centroids to new centroids
        for newCentroid in unusedNewCentroids:
            if remainingColors:
                newColorMapping[newCentroid] = remainingColors.pop()
            else:
                # Fallback if no remaining colors (this shouldn't happen with enough colors)
                newColorMapping[newCentroid] = "gray"
        
        # Update the color mapping to the new centroids
        self.colourMap = newColorMapping
    





    # main functions

    def cluster(self):

        # arbitrarily choose k objects from D as the initial cluster centres
        kDataPointsInSet = self.__defineRandomKStart()

        # assign each object to the cluster to which the object is most similar and update cluster means until no change
        mappingOld = 1
        mappingEnd = 0
        while mappingOld != mappingEnd:
            mappingOld = self.__mapAllPointsToNearestK(kDataPointsInSet)
            kDataPointsInSet = self.__calcKNewMeans(mappingOld)
            mappingEnd = self.__mapAllPointsToNearestK(kDataPointsInSet)

            self.clusterCentroids = kDataPointsInSet
            self.clusterMemberships = mappingEnd
            self.visualize()

        return(kDataPointsInSet, mappingEnd)
    

    def visualize(self):

        listWithListsX = []
        listWithListsY = []

        for centroid in self.clusterCentroids:
            oneListWithX = []
            oneListWithY = []
            for x in self.clusterMemberships[centroid]:
                oneListWithX.append(x[0])
            for y in self.clusterMemberships[centroid]:
                oneListWithY.append(y[1])
            listWithListsX.append(oneListWithX)
            listWithListsY.append(oneListWithY)
        

        for i in range(len(listWithListsX)):   
            centroid = list(self.clusterCentroids)[i] 
            plt.plot(listWithListsX[i], listWithListsY[i], "o", color=self.colourMap[centroid])
        plt.show()



    # helper function: calculate euclidean distance with 2 coordinates of the train and two coordinates of the test data 
    ### todo: can I generalize the function to take in any input coordinate length?!
    @staticmethod
    def __getEuclideanDistance(trainData1Coordinate, trainData2Coordinate, testData1Coordinate, testData2Coordinate):
        distance = math.sqrt((trainData1Coordinate-testData1Coordinate)**2+(trainData2Coordinate-testData2Coordinate)**2)
        return(distance)
    
xy_tuples = list(zip(c[0], c[1]))
newModel = KMeansClustering(xy_tuples, 2)
newModel.cluster()
newModel.visualize()
